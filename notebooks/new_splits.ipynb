# %%
import numpy as np
import os
from collections import Counter
from matplotlib import pyplot as plt
import pandas as pd
import glob

# %%
DATA_FOLDER = '../data/hmong/sch_corpus2_elab_langid'
UNTAGGED_DATA_FOLDER = '../data/hmong/sch_corpus2_conll'
NUM_FILES = 8393
FNAME = 'sch-{:05d}.conll'

# %%
def parse_one_file(path, separate_comma=False):
    with open(path) as f:
        lines = f.read().split('\n')
#     print(lines)
    elabs_in_sent = [0]
    sent_lengths = [0]
    sep = 0  # if this reaches 2, it's a new sentence
    for line in lines:
        if len(line) > 0:
            sent_lengths[-1] += 1
            if line[-1] == 'B':
                elabs_in_sent[-1] += 1
            if separate_comma and line[0] == ',':
                # start new sentence from this comma
                # new sentence
                elabs_in_sent.append(0)
                sent_lengths.append(0)    
        else:
            sep += 1
            if sep == 2:
                # new sentence
                elabs_in_sent.append(0)
                sent_lengths.append(0)
                sep = 0
                
    del elabs_in_sent[-1]
    del sent_lengths[-1]
    assert len(elabs_in_sent) == len(sent_lengths)
    return {'elabs_in_sent': elabs_in_sent, 'sent_lengths': sent_lengths}

# %% [markdown]
# ## Separate sentences as they are separated in the dataset

# %%
num_elabs = 0
num_sents_k_elab = Counter()
all_sent_lengths = []



for fn in glob.glob(os.path.join(DATA_FOLDER, '*.conll')):
    stats = parse_one_file(fn)
    elabs_in_sent, sent_lengths = stats['elabs_in_sent'], stats['sent_lengths']
    num_elabs += sum(elabs_in_sent)
    cntr = Counter(elabs_in_sent)
    num_sents_k_elab.update(cntr)

    all_sent_lengths.extend(sent_lengths)

#     all_sent_lengths.extend(sent_lengths)
# for i in range(1, NUM_FILES+1):
#     stats = parse_one_file(os.path.join(DATA_FOLDER, FNAME.format(i)))
#     elabs_in_sent, sent_lengths = stats['elabs_in_sent'], stats['sent_lengths']
#     if i in [734, 1727, 2098, 8293]:
#         print('document', i)
#         print('elabs_in_sent', elabs_in_sent)
#         print('sent_lengths', sent_lengths)
#     num_elabs += sum(elabs_in_sent)
#     cntr = Counter(elabs_in_sent)
#     num_sents_k_elab.update(cntr)

#     all_sent_lengths.extend(sent_lengths)

# %%
print("number of sentences:", len(all_sent_lengths))
print("number of elaborate expressions:", num_elabs)
print("number of sentences with k EEs:", num_sents_k_elab)
print("average sent length:", sum(all_sent_lengths)/len(all_sent_lengths))
print("total number of tokens:", sum(all_sent_lengths))
all_sent_lengths.sort(reverse=True)
# Out:
# number of sentences: 425121
# number of elaborate expressions: 24574
# number of sentences with k EEs: Counter({0: 403878, 1: 18626, 2: 2107, 3: 394, 4: 73, 5: 21, 6: 10, 7: 8, 11: 2, 8: 1, 9: 1})
# average sent length: 25.81008701052171
# total number of tokens: 10972410

# %% [markdown]
# Documents 734, 1727, 2098, 8293 have 8+ elaborate expressions?? -> because they have absurdly long sentences

# %%
def percentile(nums, k):
    # nums is sorted in descending order
    return nums[int((len(nums)-1)*k/100)]

# %%
percentile(all_sent_lengths, 1)
# Out:
# 121

# %%
plt.hist(all_sent_lengths, bins=40, log=True)
# Out:
# (array([3.32757e+05, 7.35020e+04, 1.18270e+04, 3.52400e+03, 1.51200e+03,
#         7.84000e+02, 4.40000e+02, 2.40000e+02, 1.57000e+02, 8.90000e+01,
#         7.80000e+01, 4.70000e+01, 3.20000e+01, 3.20000e+01, 2.40000e+01,
#         1.40000e+01, 1.30000e+01, 1.70000e+01, 4.00000e+00, 4.00000e+00,
#         3.00000e+00, 8.00000e+00, 4.00000e+00, 2.00000e+00, 1.00000e+00,
#         1.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00, 3.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([1.0000e+00, 3.3500e+01, 6.6000e+01, 9.8500e+01, 1.3100e+02,
#         1.6350e+02, 1.9600e+02, 2.2850e+02, 2.6100e+02, 2.9350e+02,
#         3.2600e+02, 3.5850e+02, 3.9100e+02, 4.2350e+02, 4.5600e+02,
#         4.8850e+02, 5.2100e+02, 5.5350e+02, 5.8600e+02, 6.1850e+02,
#         6.5100e+02, 6.8350e+02, 7.1600e+02, 7.4850e+02, 7.8100e+02,
#         8.1350e+02, 8.4600e+02, 8.7850e+02, 9.1100e+02, 9.4350e+02,
#         9.7600e+02, 1.0085e+03, 1.0410e+03, 1.0735e+03, 1.1060e+03,
#         1.1385e+03, 1.1710e+03, 1.2035e+03, 1.2360e+03, 1.2685e+03,
#         1.3010e+03]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# ## Separate sentences in commas as well

# %%
num_elabs_sepcomma = 0
num_sents_k_elab_sepcomma = Counter()
all_sent_lengths_sepcomma = []

for fn in glob.glob(os.path.join(DATA_FOLDER, '*.conll')):
    stats = parse_one_file(fn, separate_comma=True)
    elabs_in_sent, sent_lengths = stats['elabs_in_sent'], stats['sent_lengths']
    num_elabs += sum(elabs_in_sent)
    cntr = Counter(elabs_in_sent)
    if 5 in cntr:
        print(i)
    num_sents_k_elab_sepcomma.update(cntr)

    all_sent_lengths_sepcomma.extend(sent_lengths)
# Out:
# 23
# 23
# 23
# 23

# %%
print("number of sentences:", len(all_sent_lengths_sepcomma))
print("number of elaborate expressions:", num_elabs_sepcomma)
print("number of sentences with k EEs:", num_sents_k_elab_sepcomma)
print("average sent length:", sum(all_sent_lengths_sepcomma)/len(all_sent_lengths_sepcomma))
print("total number of tokens:", sum(all_sent_lengths_sepcomma))
all_sent_lengths_sepcomma.sort(reverse=True)
# Out:
# number of sentences: 740542
# number of elaborate expressions: 0
# number of sentences with k EEs: Counter({0: 717485, 1: 21671, 2: 1278, 3: 90, 4: 13, 5: 5})
# average sent length: 14.816728828344646
# total number of tokens: 10972410

# %%
percentile(all_sent_lengths_sepcomma, 10)
# Out:
# 29

# %% [markdown]
# Even after separating by commas, some sentences in the corpus are extremely long (a few hundred words). They are due to sentence segmentation errors. But they are rare enough in the dataset that we can safely ignore them.
#
# We can separate on a comma, then set max_len to 50 words. this will cover 98% of all the sentences.
# (or set it to 36 words to cover 95% of all sentences for faster training.)

# %% [markdown]
# ## Building a vocabulary
#
# Some rules:
# - lowercase all words
# - if a word starts with a numeral, replace it with \<NUM>

# %%
def preproc_word(w):
    if w[0].isdigit():
        return 'NUM'
    else:
        return w.lower()

def word_freqs(path):
    # use untagged data folder
    with open(path) as f:
        lines = f.read().split('\n')
#     print(lines)
    words = Counter()

    for line in lines:
        if len(line) == 0: continue
        words[preproc_word(line)] += 1
    return words

# %%
all_words = Counter()
for i in range(1, NUM_FILES+1):
    all_words.update(word_freqs(os.path.join(UNTAGGED_DATA_FOLDER, FNAME.format(i))))

# %%
def vocab_size(min_count):
    return len([w for w, c in all_words.items() if c >= min_count])

def proportion_of_unk(min_count):
    return 1-sum([c for w, c in all_words.items() if c >= min_count])/sum(all_words.values())

for min_count in range(30):
    print(min_count, vocab_size(min_count), proportion_of_unk(min_count))
# Out:
# 0 90254 0.0
# 1 90254 0.0
# 2 39088 0.0050683779318431155
# 3 27299 0.007403956536326417
# 4 21985 0.008983131789217835
# 5 18840 0.01022927560312914
# 6 16709 0.011284733658552426
# 7 15099 0.012241629464783244
# 8 13922 0.013057764511111958
# 9 12949 0.013828828378161684
# 10 12192 0.014503707376903874
# 11 11517 0.015172345750822935
# 12 10934 0.015807601734814436
# 13 10460 0.016371041004570208
# 14 10023 0.01693378687156788
# 15 9614 0.017500990327724897
# 16 9280 0.017997268587478188
# 17 8995 0.0184489709556368
# 18 8708 0.018932272678059192
# 19 8426 0.019435088735246242
# 20 8214 0.019834092493786315
# 21 7970 0.020317493273745657
# 22 7779 0.020714813054158787
# 23 7588 0.021131052824115537
# 24 7412 0.021532037733393183
# 25 7251 0.021914796055885533
# 26 7090 0.022313502641814975
# 27 6935 0.02271270451542884
# 28 6798 0.023079118344336513
# 29 6660 0.02346187666682875

# %%
sum(all_words.values())
# Out:
# 10095143

# %% [markdown]
# Can use a min_count of 10 when constructing the vocabulary.
#
# Constructing the i2w and w2i lookup
# And construct a file of sentence indices to be saved on disk

# %%
w2i = {'PAD': 0, 'UNK': 1, 'BOS': 2, 'EOS': 3}   
i2w = ['PAD', 'UNK', 'BOS', 'EOS']
# BOS may not be important in this dataset. EOS is important for batching in LSTM
for word, count in all_words.most_common():
    if count >= 10:
        w2i[word] = len(i2w)
        i2w.append(word)
        
l2i = {'PAD': 0, 'B': 3, 'I': 2, 'O': 1}
i2l = ['PAD', 'O', 'I', 'B']

# %%
def readin_one_file(path, separate_comma=True, max_sent_len=50, convert_to_idx=True):
    word_transform = preproc_word if convert_to_idx else lambda x: x
    tag_transform = l2i.get if convert_to_idx else lambda x: x
    
    with open(path) as f:
        lines = f.read().split('\n')
#     print(lines)
    sentences = [[]]
    tags = [[]]
    sep = 0  # if this reaches 2, it's a new sentence
    cur_sent_len = 0
    for line in lines:
        if len(line) > 0:
            word, tag = line.split('\t')
            if cur_sent_len < max_sent_len:
                sentences[-1].append(w2i.get(word_transform(word), w2i['UNK']))
                tags[-1].append(tag_transform(tag))
            cur_sent_len += 1
            if separate_comma and line[0] == ',':
                # start new sentence from this comma
                # new sentence
                if len(sentences[-1]) == 0:
                    print(line)
                sentences.append([])
                tags.append([])
                cur_sent_len = 0
                
        else:
            sep += 1
            if sep == 2:
                # new sentence
                sentences.append([])
                tags.append([])  
                cur_sent_len = 0
                sep = 0
                
    del sentences[-1]
    del tags[-1]
    assert len(sentences) == len(tags)
    return sentences, tags

# %%
# for character (phoneme features), generate phoneme representation of each syllable

c2i = {'PAD': 0, 'UNK': 1}
i2c = ['PAD', 'UNK']
wi2ci = {}

import sys
sys.path.append('..')
from libraries.hmong_rpa.rpa_regex import RPA_SYLLABLE as regex

def is_valid_syl(syl):
    m = regex.match(syl)
    if m:
        ons, rhy, ton = m.group("ons"), m.group("rhy"), m.group("ton")
        return ons + rhy + ton == syl
    return False

phonemes = set([])
for syl in w2i:
    m = regex.match(syl)
    if m:
        ons, rhy, ton = m.group("ons"), m.group("rhy"), m.group("ton")
        if ons + rhy + ton == syl:
            ## valid hmong syllable
            phonemes.add(f"ons_{ons}")
            phonemes.add(f"rhy_{rhy}")
            phonemes.add(f"ton_{ton}")

            
for c in sorted(phonemes):
    c2i[c] = len(i2c)
    i2c.append(c)
    
for syl in w2i:
    m = regex.match(syl)
    if m:
        ons, rhy, ton = m.group("ons"), m.group("rhy"), m.group("ton")
        if ons + rhy + ton == syl:
            ## valid hmong syllable
            wi2ci[w2i[syl]] = [c2i[f"ons_{ons}"], c2i[f"rhy_{rhy}"], c2i[f"ton_{ton}"]]

# %%
c2i
# Out:
# {'PAD': 0,
#  'UNK': 1,
#  'ons_': 2,
#  'ons_c': 3,
#  'ons_ch': 4,
#  'ons_d': 5,
#  'ons_dh': 6,
#  'ons_dl': 7,
#  'ons_dlh': 8,
#  'ons_f': 9,
#  'ons_h': 10,
#  'ons_hl': 11,
#  'ons_hm': 12,
#  'ons_hml': 13,
#  'ons_hn': 14,
#  'ons_hny': 15,
#  'ons_k': 16,
#  'ons_kh': 17,
#  'ons_l': 18,
#  'ons_m': 19,
#  'ons_ml': 20,
#  'ons_n': 21,
#  'ons_nc': 22,
#  'ons_nch': 23,
#  'ons_ndl': 24,
#  'ons_nk': 25,
#  'ons_nkh': 26,
#  'ons_np': 27,
#  'ons_nph': 28,
#  'ons_npl': 29,
#  'ons_nplh': 30,
#  'ons_nq': 31,
#  'ons_nqh': 32,
#  'ons_nr': 33,
#  'ons_nrh': 34,
#  'ons_nt': 35,
#  'ons_nth': 36,
#  'ons_nts': 37,
#  'ons_ntsh': 38,
#  'ons_ntx': 39,
#  'ons_ntxh': 40,
#  'ons_ny': 41,
#  'ons_p': 42,
#  'ons_ph': 43,
#  'ons_pl': 44,
#  'ons_plh': 45,
#  'ons_q': 46,
#  'ons_qh': 47,
#  'ons_r': 48,
#  'ons_rh': 49,
#  'ons_s': 50,
#  'ons_t': 51,
#  'ons_th': 52,
#  'ons_ts': 53,
#  'ons_tsh': 54,
#  'ons_tx': 55,
#  'ons_txh': 56,
#  'ons_v': 57,
#  'ons_x': 58,
#  'ons_xy': 59,
#  'ons_y': 60,
#  'ons_z': 61,
#  'rhy_a': 62,
#  'rhy_aa': 63,
#  'rhy_ai': 64,
#  'rhy_au': 65,
#  'rhy_aw': 66,
#  'rhy_e': 67,
#  'rhy_ee': 68,
#  'rhy_i': 69,
#  'rhy_ia': 70,
#  'rhy_o': 71,
#  'rhy_oo': 72,
#  'rhy_u': 73,
#  'rhy_ua': 74,
#  'rhy_w': 75,
#  'ton_': 76,
#  'ton_b': 77,
#  'ton_d': 78,
#  'ton_g': 79,
#  'ton_j': 80,
#  'ton_m': 81,
#  'ton_s': 82,
#  'ton_v': 83}

# %%
data_sentences = {}
data_tags = {}
for fn in glob.glob(os.path.join(DATA_FOLDER, '*.conll')):
    sentences, tags = readin_one_file(fn, separate_comma=True)
    i = os.path.basename(fn).split('.')[0].split('-')[1]
    for j, (s, t) in enumerate(zip(sentences, tags)):
        if len(s) > 0:
            identifier = f'{i}-{j:04d}'
            data_sentences[identifier] = s
            if sum(t) > len(t):  # if B or I appear in the tags
                data_tags[identifier] = t

# %%
len(data_sentences)
# Out:
# 740468

# %%
import torch

torch.save({'sentences': data_sentences, 'tags': data_tags,
            'l2i': l2i, 'i2l': i2l, 'w2i': w2i, 'i2w': i2w,
            'c2i': c2i, 'i2c': i2c, 'wi2ci': wi2ci}, '../data/hmong/data_lid.pth')

# %%
len(data_tags.keys())
# Out:
# 22735

# %% [markdown]
# ## train/val/test split of elaborate expressions
#
# ### Naive Proportion Split
# Partition all sentences without considering what EEs are tagged
#
# ![image-2.png](attachment:image-2.png)

# %%
import random
num_datasets = 3

all_sent_ids = data_sentences.keys()
for n in range(num_datasets):
    positive_ids = list(data_tags.keys())
    negative_ids = list(all_sent_ids - data_tags.keys())
    
    random.shuffle(positive_ids)
    random.shuffle(negative_ids)

    val_split = set(positive_ids[:1000]) |  set(negative_ids[:34000])
    test_split = set(positive_ids[1000:2000]) |  set(negative_ids[34000:68000])
    train_split = set(positive_ids[2000:]) |  set(negative_ids[68000:])
    
    split = {'train': train_split, 'val': val_split, 'test': test_split}
    ## uncomment to save data
    torch.save(split, f"../data/hmong/split_naive_lid_{n+1}.pth")
    
    print(list(test_split)[:10])
# Out:
# ['03076-0011', '01784-0062', '03717-0047', '06612-0045', '03530-0118', '05485-0044', '02128-0036', '06073-0067', '07346-0105', '04411-0015']
# ['05866-0116', '00134-0009', '00193-0037', '08982-0107', '06292-0009', '01439-0043', '08370-0353', '03372-0062', '06659-0083', '01102-0002']
# ['08174-0047', '00787-0071', '02048-0019', '03067-0118', '00276-0091', '02445-0088', '07831-0054', '04294-0023', '02784-0032', '02974-0004']

# %% [markdown]
# ### Expression-aware tagging
# first let's look at statistics of elaborate expressions in the corpus
# then we divide sentence ids based on which EEs appear in them, so that training set and testing set consist of disjoint EEs.

# %%
def find_elabs_in_one_file(path, separate_comma=True):
    with open(path) as f:
        lines = f.read().split('\n')
#     print(lines)
    elabs = Counter()
    sep = 0  # if this reaches 2, it's a new sentence
    cur_elab = []
    for line in lines:
        if len(line) > 0 and line[-1] != 'O':
            if line[-1] == 'B':
                cur_elab = [line.split('\t')[0]]
            elif line[-1] == 'I':
                cur_elab.append(line.split('\t')[0])
            if len(cur_elab) == 4:
#                 print(cur_elab)
                elabs[tuple(cur_elab)] += 1
                
    return elabs

all_elabs = Counter()
for fn in glob.glob(os.path.join(DATA_FOLDER, '*.conll')):
    elabs_in_this_file = find_elabs_in_one_file(fn, separate_comma=True)
    all_elabs.update(elabs_in_this_file)

# %%
all_elabs.most_common()
# Out:
# [(('tus', 'ub', 'tus', 'no'), 600),
#  (('li', 'ub', 'li', 'no'), 591),
#  (('rau', 'ub', 'rau', 'no'), 478),
#  (('ua', 'nom', 'ua', 'tswv'), 381),
#  (('coj', 'noj', 'coj', 'ua'), 347),
#  (('me', 'tub', 'me', 'nyuam'), 266),
#  (('muaj', 'noj', 'muaj', 'haus'), 226),
#  (('txhua', 'leej', 'txhua', 'tus'), 221),
#  (('muaj', 'teb', 'muaj', 'chaw'), 215),
#  (('ua', 'dog', 'ua', 'dig'), 205),
#  (('hais', 'ub', 'hais', 'no'), 190),
#  (('ua', 'teb', 'ua', 'chaw'), 189),
#  (('ua', 'noj', 'ua', 'haus'), 182),
#  (('lwm', 'leej', 'lwm', 'tus'), 165),
#  (('tim', 'ntsej', 'tim', 'muag'), 163),
#  (('kawm', 'txawj', 'kawm', 'ntse'), 148),
#  (('ua', 'pab', 'ua', 'pawg'), 147),
#  (('tau', 'noj', 'tau', 'haus'), 146),
#  (('lub', 'teb', 'lub', 'chaw'), 145),
#  (('kev', 'txawj', 'kev', 'ntse'), 144),
#  (('lub', 'koob', 'lub', 'npe'), 141),
#  (('sib', 'ntaus', 'sib', 'tua'), 140),
#  (('ua', 'hnub', 'ua', 'hmo'), 140),
#  (('dag', 'noj', 'dag', 'haus'), 140),
#  (('hav', 'zoov', 'hav', 'tsuag'), 138),
#  (('sib', 'hlub', 'sib', 'pab'), 126),
#  (('ua', 'niam', 'ua', 'txiv'), 123),
#  (('tom', 'vaj', 'tom', 'tsev'), 120),
#  (('khwv', 'noj', 'khwv', 'haus'), 115),
#  (('npaum', 'ub', 'npaum', 'no'), 115),
#  (('muag', 'noj', 'muag', 'haus'), 115),
#  (('nrhiav', 'noj', 'nrhiav', 'haus'), 113),
#  (('lus', 'paj', 'lus', 'cua'), 111),
#  (('ua', 'tsov', 'ua', 'rog'), 104),
#  (('tej', 'tub', 'tej', 'ntxhais'), 104),
#  (('ib', 'pab', 'ib', 'pawg'), 100),
#  (('tej', 'niam', 'tej', 'txiv'), 100),
#  (('tom', 'ntej', 'tom', 'qab'), 99),
#  (('chaw', 'txawb', 'chaw', 'rau'), 98),
#  (('ua', 'lag', 'ua', 'luam'), 96),
#  (('ua', 'neeb', 'ua', 'yaig'), 90),
#  (('neeg', 'txawj', 'neeg', 'ntse'), 90),
#  (('tso', 'dag', 'tso', 'luag'), 90),
#  (('kev', 'noj', 'kev', 'haus'), 90),
#  (('kev', 'neej', 'kev', 'tsav'), 89),
#  (('koj', 'niam', 'koj', 'txiv'), 89),
#  (('kev', 'ploj', 'kev', 'tuag'), 87),
#  (('lub', 'ntuj', 'lub', 'teb'), 85),
#  (('qhov', 'ub', 'qhov', 'no'), 84),
#  (('lub', 'caij', 'lub', 'nyoog'), 82),
#  (('ua', 'liaj', 'ua', 'teb'), 81),
#  (('koom', 'zej', 'koom', 'zos'), 80),
#  (('muaj', 'koob', 'muaj', 'npe'), 79),
#  (('xeeb', 'leej', 'xeeb', 'ntxwv'), 78),
#  (('paub', 'qab', 'paub', 'haus'), 77),
#  (('lwm', 'pab', 'lwm', 'pawg'), 77),
#  (('muaj', 'vaj', 'muaj', 'tsev'), 76),
#  (('qub', 'nom', 'qub', 'tswv'), 75),
#  (('hluas', 'nkauj', 'hluas', 'nraug'), 74),
#  (('nws', 'niam', 'nws', 'txiv'), 74),
#  (('kawm', 'ntaub', 'kawm', 'ntawv'), 73),
#  (('qhov', 'phem', 'qhov', 'zoo'), 73),
#  (('cov', 'niam', 'cov', 'txiv'), 73),
#  (('lub', 'dag', 'lub', 'zog'), 72),
#  (('ciam', 'dej', 'ciam', 'av'), 71),
#  (('ua', 'lwj', 'ua', 'liam'), 67),
#  (('tog', 'vaj', 'tog', 'tsev'), 65),
#  (('ua', 'zaj', 'ua', 'ntxeev'), 63),
#  (('zoo', 'nkauj', 'zoo', 'nraug'), 63),
#  (('lus', 'nyiaj', 'lus', 'kub'), 60),
#  (('kev', 'phooj', 'kev', 'ywg'), 60),
#  (('lub', 'vaj', 'lub', 'tsev'), 60),
#  (('txij', 'tog', 'txij', 'peg'), 60),
#  (('yus', 'niam', 'yus', 'txiv'), 58),
#  (('kawm', 'txuj', 'kawm', 'ci'), 57),
#  (('kev', 'lig', 'kev', 'cai'), 56),
#  (('niam', 'hlob', 'niam', 'yau'), 55),
#  (('muaj', 'siab', 'muaj', 'ntsws'), 55),
#  (('tug', 'ub', 'tug', 'nua'), 55),
#  (('lub', 'zej', 'lub', 'zos'), 55),
#  (('muaj', 'nom', 'muaj', 'tswv'), 55),
#  (('le', 'ub', 'le', 'nua'), 55),
#  (('ua', 'plaub', 'ua', 'ntug'), 54),
#  (('lawv', 'niam', 'lawv', 'txiv'), 54),
#  (('vij', 'sub', 'vij', 'sw'), 54),
#  (('muaj', 'niam', 'muaj', 'txiv'), 53),
#  (('tub', 'txawj', 'tub', 'ntse'), 52),
#  (('sib', 'ntau', 'sib', 'tua'), 52),
#  (('qub', 'teb', 'qub', 'chaw'), 49),
#  (('peb', 'niam', 'peb', 'txiv'), 49),
#  (('xav', 'mus', 'xav', 'los'), 49),
#  (('ntau', 'pab', 'ntau', 'pawg'), 49),
#  (('ua', 'kwv', 'ua', 'tij'), 48),
#  (('tej', 'nom', 'tej', 'tswv'), 48),
#  (('ua', 'ub', 'ua', 'no'), 46),
#  (('ua', 'tshoob', 'ua', 'kos'), 46),
#  (('ua', 'nkauj', 'ua', 'nraug'), 45),
#  (('lub', 'siab', 'lub', 'ntsws'), 44),
#  (('lus', 'mos', 'lus', 'muag'), 44),
#  (('cuag', 'poj', 'cuag', 'yawm'), 44),
#  (('kuv', 'niam', 'kuv', 'txiv'), 44),
#  (('muaj', 'ntaub', 'muaj', 'ntawv'), 43),
#  (('muaj', 'paus', 'muaj', 'ntsis'), 42),
#  (('ua', 'dev', 'ua', 'npua'), 42),
#  (('ua', 'neej', 'ua', 'tsav'), 42),
#  (('tim', 'ub', 'tim', 'no'), 41),
#  (('txhua', 'leej', 'txhua', 'tug'), 41),
#  (('muaj', 'yeej', 'muaj', 'swb'), 41),
#  (('haus', 'dej', 'haus', 'cawv'), 40),
#  (('hauv', 'vaj', 'hauv', 'tsev'), 40),
#  (('tso', 'daj', 'tso', 'luag'), 39),
#  (('siab', 'loj', 'siab', 'dav'), 39),
#  (('hais', 'mus', 'hais', 'los'), 39),
#  (('ua', 'phooj', 'ua', 'ywg'), 39),
#  (('ua', 'dab', 'ua', 'qhua'), 38),
#  (('cov', 'tub', 'cov', 'ntxhais'), 38),
#  (('tej', 'kwv', 'tej', 'tij'), 38),
#  (('yog', 'kwv', 'yog', 'tij'), 37),
#  (('muaj', 'nyiaj', 'muaj', 'txiaj'), 37),
#  (('cov', 'nom', 'cov', 'tswv'), 37),
#  (('tub', 'lag', 'tub', 'luam'), 36),
#  (('ua', 'kub', 'ua', 'ntaiv'), 36),
#  (('ua', 'ciaj', 'ua', 'tuag'), 36),
#  (('ua', 'vaj', 'ua', 'tsev'), 36),
#  (('kev', 'lis', 'kev', 'cai'), 36),
#  (('cais', 'pab', 'cais', 'pawg'), 36),
#  (('lwm', 'leej', 'lwm', 'tug'), 36),
#  (('kev', 'nom', 'kev', 'tswv'), 35),
#  (('muaj', 'qab', 'muaj', 'hau'), 35),
#  (('lub', 'ntsej', 'lub', 'muag'), 35),
#  (('koj', 'pog', 'koj', 'yawg'), 35),
#  (('tsis', 'paub', 'tsis', 'pom'), 35),
#  (('txoj', 'kev', 'txoj', 'cai'), 34),
#  (('ua', 'zaub', 'ua', 'mov'), 34),
#  (('ua', 'mus', 'ua', 'los'), 34),
#  (('kev', 'nkauj', 'kev', 'nraug'), 34),
#  (('lus', 'dev', 'lus', 'npua'), 34),
#  (('luag', 'poj', 'luag', 'sev'), 34),
#  (('saib', 'mus', 'saib', 'los'), 33),
#  (('kev', 'kwv', 'kev', 'tij'), 33),
#  (('tau', 'ntsej', 'tau', 'muag'), 33),
#  (('qhov', 'zoo', 'qhov', 'phem'), 33),
#  (('kuag', 'kaab', 'kuag', 'hlau'), 32),
#  (('qhuas', 'qab', 'qhuas', 'tsau'), 31),
#  (('ntau', 'leej', 'ntau', 'tus'), 31),
#  (('yog', 'niam', 'yog', 'txiv'), 31),
#  (('tas', 'zaj', 'tas', 'zog'), 31),
#  (('lug', 'toj', 'lug', 'pes'), 31),
#  (('puv', 'roob', 'puv', 'hav'), 31),
#  (('muaj', 'kwv', 'muaj', 'tij'), 30),
#  (('yog', 'neej', 'yog', 'tsav'), 30),
#  (('tej', 'txheeb', 'tej', 'ze'), 30),
#  (('luag', 'teb', 'luag', 'chaw'), 30),
#  (('muaj', 'plaub', 'muaj', 'ntug'), 30),
#  (('qhov', 'txhia', 'qhov', 'chaw'), 30),
#  (('ib', 'txhiab', 'ib', 'txhis'), 30),
#  (('txiv', 'hmab', 'txiv', 'ntoo'), 30),
#  (('dab', 'vaj', 'dab', 'tsev'), 29),
#  (('tub', 'sab', 'tub', 'nyiag'), 29),
#  (('tus', 'ntsuj', 'tus', 'plig'), 29),
#  (('ua', 'plees', 'ua', 'yi'), 29),
#  (('tus', 'phem', 'tus', 'zoo'), 28),
#  (('raws', 'noj', 'raws', 'haus'), 28),
#  (('txog', 'vaj', 'txog', 'tsev'), 28),
#  (('rooj', 'noj', 'rooj', 'haus'), 28),
#  (('tej', 'nam', 'tej', 'txiv'), 28),
#  (('txhia', 'leej', 'txhia', 'tus'), 28),
#  (('niaj', 'hnub', 'niaj', 'hmo'), 27),
#  (('raug', 'ploj', 'raug', 'tuag'), 27),
#  (('muaj', 'ntsej', 'muaj', 'muag'), 27),
#  (('ua', 'dlog', 'ua', 'dlig'), 27),
#  (('tau', 'koob', 'tau', 'npe'), 27),
#  (('sib', 'txheeb', 'sib', 'ze'), 26),
#  (('xws', 'teb', 'xws', 'chaw'), 26),
#  (('kev', 'phem', 'kev', 'qias'), 26),
#  (('lug', 'nyaj', 'lug', 'kub'), 26),
#  (('tsis', 'pom', 'tsis', 'paub'), 26),
#  (('lus', 'xaiv', 'lus', 'ncua'), 26),
#  (('kis', 'toj', 'kis', 'pes'), 25),
#  (('tswv', 'teb', 'tswv', 'chaw'), 25),
#  (('ywj', 'fab', 'ywj', 'fwj'), 25),
#  (('tus', 'laus', 'tus', 'hluas'), 25),
#  (('kev', 'txheeb', 'kev', 'ze'), 25),
#  (('muaj', 'tseeb', 'muaj', 'tsum'), 25),
#  (('kev', 'plees', 'kev', 'yi'), 25),
#  (('tsa', 'nom', 'tsa', 'tswv'), 25),
#  (('hais', 'phem', 'hais', 'zoo'), 25),
#  (('pab', 'ub', 'pab', 'no'), 25),
#  (('ntau', 'tsav', 'ntau', 'yam'), 25),
#  (('yuav', 'noj', 'yuav', 'haus'), 25),
#  (('txhua', 'hnub', 'txhua', 'hmo'), 25),
#  (('hlawv', 'xyab', 'hlawv', 'ntawv'), 25),
#  (('ua', 'phab', 'ua', 'pheev'), 24),
#  (('kev', 'lag', 'kev', 'luam'), 24),
#  (('ua', 'sab', 'ua', 'sua'), 24),
#  (('nriav', 'noj', 'nriav', 'haus'), 24),
#  (('tham', 'mus', 'tham', 'los'), 24),
#  (('cov', 'txheeb', 'cov', 'ze'), 24),
#  (('yuav', 'ciaj', 'yuav', 'tuag'), 23),
#  (('poj', 'nrauj', 'poj', 'ntsuam'), 23),
#  (('zoo', 'caij', 'zoo', 'nyoog'), 23),
#  (('tau', 'nom', 'tau', 'tswv'), 23),
#  (('tus', 'txheeb', 'tus', 'ze'), 23),
#  (('tsis', 'mus', 'tsis', 'los'), 23),
#  (('nyias', 'vaj', 'nyias', 'tsev'), 23),
#  (('qhov', 'ntsej', 'qhov', 'muag'), 23),
#  (('huab', 'noj', 'huab', 'haus'), 22),
#  (('muaj', 'liaj', 'muaj', 'teb'), 22),
#  (('dhia', 'siab', 'dhia', 'nqi'), 22),
#  (('me', 'tub', 'me', 'ntxhais'), 22),
#  (('lob', 'ub', 'lob', 'no'), 22),
#  (('poob', 'teb', 'poob', 'chaw'), 22),
#  (('keb', 'ub', 'keb', 'no'), 22),
#  (('raug', 'kev', 'raug', 'cai'), 22),
#  (('ua', 'num', 'ua', 'tswv'), 22),
#  (('sib', 'pab', 'sib', 'hlub'), 21),
#  (('tus', 'hlob', 'tus', 'yau'), 21),
#  (('nyiaj', 'hnub', 'nyiaj', 'hli'), 21),
#  (('yam', 'ub', 'yam', 'no'), 21),
#  (('ntees', 'ploj', 'ntees', 'tuag'), 21),
#  (('tom', 'ntej', 'tom', 'qaab'), 21),
#  (('ntawv', 'noj', 'ntawv', 'haus'), 21),
#  (('cua', 'daj', 'cua', 'dub'), 21),
#  (('ua', 'rwj', 'ua', 'aws'), 21),
#  (('tej', 'tub', 'tej', 'ki'), 21),
#  (('hauv', 'zej', 'hauv', 'zos'), 21),
#  (('tsis', 'tag', 'tsis', 'kawg'), 21),
#  (('ua', 'loj', 'ua', 'lug'), 21),
#  (('tsi', 'mus', 'tsi', 'los'), 21),
#  (('ua', 'ntsej', 'ua', 'muag'), 21),
#  (('yog', 'nom', 'yog', 'tswv'), 21),
#  (('ua', 'nam', 'ua', 'txiv'), 21),
#  (('nyias', 'pab', 'nyias', 'pawg'), 21),
#  (('neeg', 'dawb', 'neeg', 'huv'), 21),
#  (('liam', 'ub', 'liam', 'no'), 21),
#  (('tshum', 'ub', 'tshum', 'no'), 20),
#  (('xaiv', 'ntsej', 'xaiv', 'muag'), 20),
#  (('luag', 'niam', 'luag', 'txiv'), 20),
#  (('hauv', 'paus', 'hauv', 'ntsis'), 20),
#  (('pw', 'noj', 'pw', 'haus'), 20),
#  (('sib', 'hlub', 'sib', 'paab'), 20),
#  (('tas', 'hnub', 'tas', 'hmo'), 20),
#  (('tsis', 'mob', 'tsis', 'khaus'), 20),
#  (('cov', 'kwv', 'cov', 'tij'), 20),
#  (('raug', 'cuab', 'raug', 'khi'), 20),
#  (('muaj', 'pab', 'muaj', 'pawg'), 20),
#  (('noj', 'teb', 'noj', 'chaw'), 19),
#  (('nwg', 'nam', 'nwg', 'txiv'), 19),
#  (('ua', 'laj', 'ua', 'kam'), 19),
#  (('txoj', 'kab', 'txoj', 'kev'), 19),
#  (('tsi', 'txawj', 'tsi', 'ntse'), 19),
#  (('yuav', 'vaj', 'yuav', 'tsev'), 19),
#  (('txiv', 'neeb', 'txiv', 'yaig'), 19),
#  (('muaj', 'caub', 'muaj', 'chim'), 19),
#  (('raws', 'kev', 'raws', 'cai'), 19),
#  (('paub', 'ntaub', 'paub', 'ntawv'), 19),
#  (('ua', 'phem', 'ua', 'qias'), 19),
#  (('dej', 'siab', 'dej', 'ntsws'), 18),
#  (('muaj', 'suab', 'muaj', 'npe'), 18),
#  (('kev', 'neej', 'kev', 'tsaav'), 18),
#  (('suav', 'hnub', 'suav', 'hmo'), 18),
#  (('txog', 'caij', 'txog', 'nyoog'), 18),
#  (('yus', 'vaj', 'yus', 'tsev'), 18),
#  (('rua', 'ub', 'rua', 'nua'), 18),
#  (('pluas', 'noj', 'pluas', 'haus'), 18),
#  (('thov', 'ntuj', 'thov', 'teb'), 18),
#  (('ua', 'dej', 'ua', 'num'), 18),
#  (('tsog', 'lej', 'tsog', 'laus'), 18),
#  (('xya', 'niaj', 'xya', 'xyoo'), 18),
#  (('ua', 'tab', 'ua', 'tauv'), 17),
#  (('nej', 'niam', 'nej', 'txiv'), 17),
#  (('pab', 'nyiaj', 'pab', 'txiaj'), 17),
#  (('kev', 'iab', 'kev', 'daw'), 17),
#  (('kawg', 'siab', 'kawg', 'ntsws'), 17),
#  (('hmoob', 'neej', 'hmoob', 'tsav'), 17),
#  (('tu', 'tub', 'tu', 'kiv'), 17),
#  (('paub', 'qab', 'paub', 'hau'), 17),
#  (('tsis', 'deb', 'tsis', 'ze'), 17),
#  (('rov', 'qab', 'rov', 'quav'), 17),
#  (('yawm', 'yij', 'yawm', 'dab'), 17),
#  (('kuag', 'kab', 'kuag', 'hlau'), 17),
#  (('tseem', 'kev', 'tseem', 'cai'), 17),
#  (('yog', 'kev', 'yog', 'cai'), 17),
#  (('tug', 'ub', 'tug', 'nuav'), 17),
#  (('kwv', 'tij', 'kwv', 'npawg'), 17),
#  (('pom', 'ntsej', 'pom', 'muag'), 17),
#  (('ua', 'nuj', 'ua', 'nqi'), 17),
#  (('paub', 'ub', 'paub', 'no'), 17),
#  (('dab', 'ntuj', 'dab', 'teb'), 17),
#  (('tiv', 'tshav', 'tiv', 'nag'), 16),
#  (('lus', 'nom', 'lus', 'tswv'), 16),
#  (('luag', 'noj', 'luag', 'haus'), 16),
#  (('txhua', 'tsav', 'txhua', 'yam'), 16),
#  (('ua', 'nruj', 'ua', 'tsiv'), 16),
#  (('sib', 'pab', 'sib', 'txhawb'), 16),
#  (('khoom', 'vaj', 'khoom', 'tsev'), 16),
#  (('zoo', 'ntsej', 'zoo', 'muag'), 16),
#  (('tej', 'phooj', 'tej', 'ywg'), 16),
#  (('tsis', 'txheeb', 'tsis', 'ze'), 16),
#  (('mus', 'noj', 'mus', 'haus'), 16),
#  (('tau', 'teb', 'tau', 'chaw'), 16),
#  (('nrhav', 'noj', 'nrhav', 'haus'), 16),
#  (('siab', 'loj', 'siab', 'ntev'), 16),
#  (('nqi', 'mis', 'nqi', 'hno'), 16),
#  (('le', 'ub', 'le', 'nuav'), 16),
#  (('lwm', 'paab', 'lwm', 'pawg'), 16),
#  (('dlaag', 'noj', 'dlaag', 'haus'), 16),
#  (('ncig', 'zej', 'ncig', 'zos'), 16),
#  (('vuag', 'ub', 'vuag', 'no'), 16),
#  (('fim', 'ntsej', 'fim', 'muag'), 16),
#  (('nws', 'kwv', 'nws', 'tij'), 15),
#  (('tsis', 'txawj', 'tsis', 'ntse'), 15),
#  (('yuav', 'ntsej', 'yuav', 'muag'), 15),
#  (('tus', 'yeej', 'tus', 'swb'), 15),
#  (('raug', 'ntsej', 'raug', 'muag'), 15),
#  (('ua', 'mab', 'ua', 'suav'), 15),
#  (('sib', 'caav', 'sib', 'tshe'), 15),
#  (('mus', 'ub', 'mus', 'no'), 15),
#  (('tej', 'siab', 'tej', 'ntsws'), 15),
#  (('coob', 'leej', 'coob', 'tus'), 15),
#  (('ua', 'txij', 'ua', 'nkawm'), 15),
#  (('ncig', 'ntuj', 'ncig', 'teb'), 15),
#  (('kom', 'yeej', 'kom', 'swb'), 15),
#  (('lawv', 'vaj', 'lawv', 'tsev'), 15),
#  (('kev', 'tshoob', 'kev', 'kos'), 15),
#  (('yug', 'nam', 'yug', 'txiv'), 15),
#  (('tuam', 'meej', 'tuam', 'pem'), 15),
#  (('tus', 'ruam', 'tus', 'ntse'), 14),
#  (('ciaj', 'nom', 'ciaj', 'tswv'), 14),
#  (('kev', 'dab', 'kev', 'qhua'), 14),
#  (('sau', 'ntaub', 'sau', 'ntawv'), 14),
#  (('mloog', 'qab', 'mloog', 'hauv'), 14),
#  (('hais', 'siab', 'hais', 'qis'), 14),
#  (('kam', 'teb', 'kam', 'chaw'), 14),
#  (('laug', 'hnub', 'laug', 'hmo'), 14),
#  (('cam', 'dlej', 'cam', 'aav'), 14),
#  (('yuav', 'txawj', 'yuav', 'ntse'), 14),
#  (('coj', 'tshoob', 'coj', 'kos'), 14),
#  (('los', 'coj', 'los', 'ua'), 14),
#  (('kev', 'pluj', 'kev', 'tuag'), 14),
#  (('tso', 'vaj', 'tso', 'tsev'), 14),
#  (('dab', 'niam', 'dab', 'txiv'), 14),
#  (('tsis', 'meej', 'tsis', 'pem'), 14),
#  (('dag', 'nom', 'dag', 'tswv'), 14),
#  (('hauv', 'paug', 'hauv', 'ntsis'), 14),
#  (('khoom', 'noj', 'khoom', 'haus'), 13),
#  (('poob', 'ntsej', 'poob', 'muag'), 13),
#  (('tsi', 'deb', 'tsi', 'ze'), 13),
#  (('ua', 'vij', 'ua', 'swv'), 13),
#  (('khwv', 'ciaj', 'khwv', 'tuag'), 13),
#  (('tas', 'phab', 'tas', 'pheev'), 13),
#  (('tu', 'vaj', 'tu', 'tsev'), 13),
#  (('me', 'kab', 'me', 'ntsaum'), 13),
#  (('thawm', 'niaj', 'thawm', 'xyoo'), 13),
#  (('ua', 'nub', 'ua', 'mo'), 13),
#  (('tsi', 'meej', 'tsi', 'pem'), 13),
#  (('yog', 'phooj', 'yog', 'ywg'), 13),
#  (('nrog', 'huab', 'nrog', 'cua'), 13),
#  (('muaj', 'txuj', 'muaj', 'ci'), 13),
#  (('txiv', 'laus', 'txiv', 'hluas'), 13),
#  (('cov', 'tub', 'cov', 'kiv'), 13),
#  (('tua', 'tsiaj', 'tua', 'txhuv'), 13),
#  (('qub', 'vaj', 'qub', 'tsev'), 12),
#  (('muab', 'nyiaj', 'muab', 'txiaj'), 12),
#  (('lub', 'paus', 'lub', 'ntsis'), 12),
#  (('poob', 'nyiaj', 'poob', 'txiaj'), 12),
#  (('noj', 'dawb', 'noj', 'do'), 12),
#  (('tswv', 'ntuj', 'tswv', 'teb'), 12),
#  (('kes', 'tes', 'kes', 'taw'), 12),
#  (('tau', 'kwv', 'tau', 'tij'), 12),
#  (('yeej', 'koob', 'yeej', 'huam'), 12),
#  (('lub', 'koob', 'lub', 'meej'), 12),
#  (('ua', 'paab', 'ua', 'pawg'), 12),
#  (('sib', 'daj', 'sib', 'dee'), 12),
#  (('ua', 'ntaub', 'ua', 'ntawv'), 12),
#  (('tub', 'nom', 'tub', 'tswv'), 12),
#  (('muaj', 'txij', 'muaj', 'nkawm'), 12),
#  (('muaj', 'vaaj', 'muaj', 'tsev'), 12),
#  (('qhua', 'qab', 'qhua', 'tsau'), 12),
#  (('lug', 'paaj', 'lug', 'cua'), 12),
#  (('khau', 'maj', 'khau', 'ntuag'), 12),
#  (('niam', 'laus', 'niam', 'hluas'), 12),
#  (('puas', 'tsav', 'puas', 'yam'), 12),
#  (('tus', 'nom', 'tus', 'tswv'), 12),
#  (('siv', 'riam', 'siv', 'phom'), 12),
#  (('leej', 'niam', 'leej', 'txiv'), 12),
#  (('saib', 'neej', 'saib', 'tsav'), 12),
#  (('raug', 'plaub', 'raug', 'ntug'), 12),
#  (('peb', 'nam', 'peb', 'txiv'), 12),
#  (('xav', 'neej', 'xav', 'tsav'), 12),
#  (('muaj', 'cag', 'muaj', 'ceg'), 12),
#  (('cov', 'nam', 'cov', 'txiv'), 12),
#  (('ua', 'txwj', 'ua', 'nkawm'), 12),
#  (('yuav', 'poj', 'yuav', 'sev'), 12),
#  (('paub', 'kwv', 'paub', 'tij'), 12),
#  (('yog', 'txheeb', 'yog', 'ze'), 11),
#  (('qub', 'zej', 'qub', 'zog'), 11),
#  (('hais', 'ciaj', 'hais', 'tuag'), 11),
#  (('tua', 'nyuj', 'tua', 'twm'), 11),
#  (('paub', 'siab', 'paub', 'qis'), 11),
#  (('pom', 'ub', 'pom', 'no'), 11),
#  (('hais', 'plaub', 'hais', 'ntug'), 11),
#  (('tog', 'vaaj', 'tog', 'tsev'), 11),
#  (('muab', 'nom', 'muab', 'tswv'), 11),
#  (('txhua', 'pab', 'txhua', 'pawg'), 11),
#  (('nai', 'phoo', 'nai', 'pha'), 11),
#  (('qhov', 'siab', 'qhov', 'qis'), 11),
#  (('txam', 'zeb', 'txam', 'tsua'), 11),
#  (('lub', 'zej', 'lub', 'zog'), 11),
#  (('chaws', 'txawb', 'chaws', 'rau'), 11),
#  (('ua', 'phem', 'ua', 'zoo'), 11),
#  (('dej', 'kub', 'dej', 'npau'), 11),
#  (('muaj', 'neej', 'muaj', 'tsav'), 11),
#  (('ntxias', 'noj', 'ntxias', 'qhe'), 11),
#  (('tus', 'loj', 'tus', 'me'), 11),
#  (('ntsia', 'mus', 'ntsia', 'los'), 11),
#  (('nta', 'dab', 'nta', 'qhua'), 11),
#  (('vaaj', 'luj', 'vaaj', 'miv'), 11),
#  (('has', 'ub', 'has', 'nua'), 11),
#  (('kev', 'phem', 'kev', 'zoo'), 11),
#  (('kaug', 'ub', 'kaug', 'no'), 11),
#  (('nam', 'hlub', 'nam', 'yau'), 11),
#  (('tej', 'vaj', 'tej', 'tsev'), 11),
#  (('neeg', 'ncaj', 'neeg', 'ncees'), 11),
#  (('poj', 'dab', 'poj', 'ntsuag'), 11),
#  (('kwv', 'riam', 'kwv', 'phom'), 11),
#  (('lav', 'tshoob', 'lav', 'kos'), 11),
#  (('koom', 'niam', 'koom', 'txiv'), 11),
#  (('puab', 'nam', 'puab', 'txiv'), 11),
#  (('tus', 'txiaj', 'tus', 'ntsim'), 11),
#  (('raug', 'thuv', 'raug', 'txim'), 11),
#  (('sis', 'ntaus', 'sis', 'tua'), 11),
#  (('tuaj', 'noj', 'tuaj', 'haus'), 10),
#  (('noj', 'seem', 'noj', 'so'), 10),
#  (('tub', 'mab', 'tub', 'qhe'), 10),
#  (('caum', 'noj', 'caum', 'haus'), 10),
#  (('siv', 'dag', 'siv', 'zog'), 10),
#  (('ntxias', 'noj', 'ntxias', 'haus'), 10),
#  (('tso', 'quav', 'tso', 'zis'), 10),
#  (('yaam', 'ub', 'yaam', 'nua'), 10),
#  (('txaus', 'noj', 'txaus', 'haus'), 10),
#  (('koj', 'kwv', 'koj', 'tij'), 10),
#  (('mus', 'vaj', 'mus', 'tsev'), 10),
#  (('ua', 'neej', 'ua', 'tsaav'), 10),
#  (('dab', 'txeej', 'dab', 'qus'), 10),
#  (('tug', 'dab', 'tug', 'qhua'), 10),
#  (('kaum', 'roob', 'kaum', 'hav'), 10),
#  (('tsev', 'zeb', 'tsev', 'tsua'), 10),
#  (('sib', 'ntsib', 'sib', 'tham'), 10),
#  (('ua', 'txhij', 'ua', 'txhua'), 10),
#  (('puas', 'koob', 'puas', 'npe'), 10),
#  (('ua', 'txuj', 'ua', 'ci'), 10),
#  (('has', 'moog', 'has', 'lug'), 10),
#  (('tus', 'tub', 'tus', 'ntxhais'), 10),
#  (('ua', 'kub', 'ua', 'ceev'), 10),
#  (('txaj', 'ntshaa', 'txaj', 'ntsim'), 10),
#  (('quav', 'dej', 'quav', 'cawv'), 10),
#  (('kev', 'plaub', 'kev', 'ntug'), 10),
#  (('hwm', 'niam', 'hwm', 'txiv'), 10),
#  (('kua', 'tooj', 'kua', 'hlau'), 10),
#  (('ncig', 'mus', 'ncig', 'los'), 10),
#  (('pa', 'hlob', 'pa', 'yau'), 10),
#  (('los', 'noj', 'los', 'haus'), 10),
#  (('lus', 'plaub', 'lus', 'ntug'), 10),
#  (('koom', 'siab', 'koom', 'ntsws'), 10),
#  (('ib', 'paab', 'ib', 'pawg'), 10),
#  (('kev', 'phem', 'kev', 'qas'), 10),
#  (('qhov', 'quav', 'qhov', 'zis'), 10),
#  (('ua', 'lwj', 'ua', 'lam'), 10),
#  (('ua', 'kev', 'ua', 'cai'), 10),
#  (('dag', 'teb', 'dag', 'chaw'), 10),
#  (('hniav', 'ntaj', 'hniav', 'riam'), 10),
#  (('sib', 'daj', 'sib', 'deev'), 10),
#  (('lwg', 'noj', 'lwg', 'haus'), 10),
#  (('luag', 'poj', 'luag', 'txiv'), 10),
#  (('qub', 'zej', 'qub', 'zos'), 9),
#  (('lug', 'dlev', 'lug', 'npua'), 9),
#  (('ua', 'ntej', 'ua', 'qab'), 9),
#  (('lus', 'xaiv', 'lus', 'cua'), 9),
#  (('txug', 'caij', 'txug', 'nyoog'), 9),
#  (('zeem', 'neej', 'zeem', 'tsav'), 9),
#  (('puas', 'siab', 'puas', 'ntsws'), 9),
#  (('xeeb', 'teb', 'xeeb', 'chaw'), 9),
#  (('tag', 'siab', 'tag', 'ntsws'), 9),
#  (('tso', 'dlaag', 'tso', 'luag'), 9),
#  (('vij', 'sub', 'vij', 'npog'), 9),
#  (('li', 'teb', 'li', 'chaw'), 9),
#  (('lus', 'txawj', 'lus', 'ntse'), 9),
#  (('xeeb', 'luj', 'xeeb', 'lam'), 9),
#  (('yus', 'kwv', 'yus', 'tij'), 9),
#  (('tiav', 'niam', 'tiav', 'txiv'), 9),
#  (('luag', 'vaj', 'luag', 'tsev'), 9),
#  (('hnov', 'ub', 'hnov', 'no'), 9),
#  (('nug', 'mus', 'nug', 'los'), 9),
#  (('twm', 'zeej', 'twm', 'kawv'), 9),
#  (('vwm', 'loj', 'vwm', 'leg'), 9),
#  (('dab', 'teb', 'dab', 'chaw'), 9),
#  (('muaj', 'tub', 'muaj', 'ntxhais'), 9),
#  (('xeem', 'ub', 'xeem', 'no'), 9),
#  (('muaj', 'phooj', 'muaj', 'ywg'), 9),
#  (('cov', 'txawj', 'cov', 'ntse'), 9),
#  (('tsa', 'tes', 'tsa', 'taw'), 9),
#  (('muab', 'ub', 'muab', 'no'), 9),
#  (('nplooj', 'hmab', 'nplooj', 'ntoo'), 9),
#  (('ib', 'hnub', 'ib', 'hmo'), 9),
#  (('kev', 'coj', 'kev', 'ua'), 9),
#  (('lub', 'roob', 'lub', 'hav'), 9),
#  (('hu', 'ntuj', 'hu', 'teb'), 9),
#  (('kev', 'txog', 'kev', 'txhaum'), 9),
#  (('ib', 'tsob', 'ib', 'txoog'), 9),
#  (('muaj', 'tsov', 'muaj', 'rog'), 9),
#  (('cuag', 'puj', 'cuag', 'yawm'), 9),
#  (('kav', 'teb', 'kav', 'chaw'), 9),
#  (('npaum', 'ub', 'npaum', 'nua'), 9),
#  (('kom', 'txhij', 'kom', 'txhua'), 9),
#  (('paub', 'siab', 'paub', 'nqi'), 9),
#  (('koom', 'poj', 'koom', 'yawm'), 9),
#  (('khib', 'ciaj', 'khib', 'tuag'), 9),
#  (('mus', 'ntoj', 'mus', 'thuv'), 9),
#  (('sib', 'pab', 'sib', 'koom'), 9),
#  (('mus', 'dawb', 'mus', 'huv'), 9),
#  (('phem', 'tes', 'phem', 'taw'), 9),
#  (('tis', 'tshoob', 'tis', 'kos'), 9),
#  (('leej', 'nam', 'leej', 'txiv'), 9),
#  (('dag', 'ub', 'dag', 'no'), 9),
#  (('hlub', 'niam', 'hlub', 'txiv'), 9),
#  (('cuag', 'pog', 'cuag', 'yawg'), 9),
#  (('tej', 'zej', 'tej', 'zos'), 9),
#  (('tom', 'zej', 'tom', 'zos'), 9),
#  (('yog', 'caij', 'yog', 'nyoog'), 9),
#  (('koom', 'zej', 'koom', 'zog'), 9),
#  (('phom', 'loj', 'phom', 'me'), 9),
#  (('tus', 'txawj', 'tus', 'ntse'), 9),
#  (('ti', 'tes', 'ti', 'taw'), 8),
#  (('ntshav', 'ntsej', 'ntshav', 'ntswg'), 8),
#  (('mloog', 'niam', 'mloog', 'txiv'), 8),
#  (('tsis', 'txwv', 'tsis', 'txiav'), 8),
#  (('raug', 'ntes', 'raug', 'kaw'), 8),
#  (('ntau', 'yam', 'ntau', 'tsav'), 8),
#  (('hais', 'txhij', 'hais', 'txhua'), 8),
#  (('qhov', 'nyiaj', 'qhov', 'kub'), 8),
#  (('ua', 'dlej', 'ua', 'num'), 8),
#  (('kev', 'chawj', 'kev', 'chim'), 8),
#  (('hav', 'tauj', 'hav', 'nqeeb'), 8),
#  (('dhau', 'kev', 'dhau', 'cai'), 8),
#  (('seem', 'kev', 'seem', 'cai'), 8),
#  (('puv', 'zej', 'puv', 'zos'), 8),
#  (('xav', 'txhij', 'xav', 'txhua'), 8),
#  (('tej', 'ntaub', 'tej', 'ntawv'), 8),
#  (('puag', 'tes', 'puag', 'taw'), 8),
#  (('sib', 'ceg', 'sib', 'ntaus'), 8),
#  (('sib', 'chab', 'sib', 'chaws'), 8),
#  (('kaus', 'noj', 'kaus', 'haus'), 8),
#  (('miv', 'tub', 'miv', 'ntxhais'), 8),
#  (('muaj', 'laj', 'muaj', 'kam'), 8),
#  (('cov', 'neej', 'cov', 'tsav'), 8),
#  (('ua', 'qeej', 'ua', 'nruas'), 8),
#  (('miv', 'tub', 'miv', 'nyuas'), 8),
#  (('rau', 'pem', 'rau', 'nram'), 8),
#  (('qhov', 'riam', 'qhov', 'phom'), 8),
#  (('tau', 'pab', 'tau', 'pawg'), 8),
#  (('cog', 'qoob', 'cog', 'loo'), 8),
#  (('tsis', 'yog', 'tsis', 'zoo'), 8),
#  (('tswv', 'zej', 'tswv', 'zos'), 8),
#  (('thoob', 'teb', 'thoob', 'chaw'), 8),
#  (('nqa', 'riam', 'nqa', 'phom'), 8),
#  (('muaj', 'ploj', 'muaj', 'tuag'), 8),
#  (('rooj', 'nom', 'rooj', 'tswv'), 8),
#  (('qhov', 'dev', 'qhov', 'npua'), 8),
#  (('mus', 'haub', 'mus', 'ntxias'), 8),
#  (('noob', 'nom', 'noob', 'tswv'), 8),
#  (('me', 'ntswb', 'me', 'ntsis'), 8),
#  (('rau', 'teb', 'rau', 'chaw'), 8),
#  (('sib', 'hlub', 'sib', 'hwm'), 8),
#  (('koj', 'noj', 'koj', 'haus'), 8),
#  (('lawv', 'noj', 'lawv', 'haus'), 8),
#  (('muaj', 'txhij', 'muaj', 'txhua'), 8),
#  (('muab', 'roj', 'muab', 'ntshav'), 8),
#  (('qub', 'zaub', 'qub', 'mov'), 8),
#  (('puv', 'vaj', 'puv', 'tsev'), 8),
#  (('ntsuag', 'niam', 'ntsuag', 'txiv'), 8),
#  (('tshwm', 'ntsej', 'tshwm', 'muag'), 8),
#  (('haum', 'kab', 'haum', 'kev'), 8),
#  (('lus', 'phem', 'lus', 'zoo'), 8),
#  (('nqaij', 'txhiab', 'nqaij', 'ci'), 8),
#  (('raws', 'kab', 'raws', 'kev'), 8),
#  (('txawj', 'mob', 'txawj', 'tuag'), 8),
#  (('lub', 'vaaj', 'lub', 'tsev'), 8),
#  (('tsev', 'ploj', 'tsev', 'tuag'), 8),
#  (('tom', 'ub', 'tom', 'no'), 8),
#  (('xav', 'kwv', 'xav', 'tij'), 8),
#  (('laug', 'caij', 'laug', 'nyoog'), 8),
#  (('puv', 'vaaj', 'puv', 'tsev'), 8),
#  (('kuv', 'pog', 'kuv', 'yawg'), 7),
#  (('nug', 'ub', 'nug', 'no'), 7),
#  (('hmoob', 'teej', 'hmoob', 'tug'), 7),
#  (('kev', 'neej', 'kev', 'tsa'), 7),
#  (('yeej', 'teb', 'yeej', 'chaw'), 7),
#  (('yus', 'poj', 'yus', 'yawm'), 7),
#  (('dab', 'ub', 'dab', 'no'), 7),
#  (('rau', 'nom', 'rau', 'tswv'), 7),
#  (('noj', 'zaub', 'noj', 'mov'), 7),
#  (('nyias', 'dab', 'nyias', 'qhua'), 7),
#  (('tso', 'riam', 'tso', 'phom'), 7),
#  (('tus', 'neej', 'tus', 'tsav'), 7),
#  (('tub', 'ntsoj', 'tub', 'ntsuag'), 7),
#  (('lawv', 'kwv', 'lawv', 'tij'), 7),
#  (('tag', 'phab', 'tag', 'pheev'), 7),
#  (('muab', 'vaj', 'muab', 'tsev'), 7),
#  (('tuav', 'tes', 'tuav', 'taw'), 7),
#  (('taag', 'zaaj', 'taag', 'zug'), 7),
#  (('raws', 'kwv', 'raws', 'tij'), 7),
#  (('ntaim', 'noj', 'ntaim', 'haus'), 7),
#  (('tua', 'nas', 'tua', 'noog'), 7),
#  (('txhaum', 'kev', 'txhaum', 'cai'), 7),
#  (('saib', 'moog', 'saib', 'lug'), 7),
#  (('tsheej', 'phab', 'tsheej', 'pheev'), 7),
#  (('muaj', 'qab', 'muaj', 'quas'), 7),
#  (('quav', 'yeeb', 'quav', 'tshuaj'), 7),
#  (('tub', 'maab', 'tub', 'qhe'), 7),
#  (('tshum', 'lwj', 'tshum', 'liam'), 7),
#  (('ntau', 'paab', 'ntau', 'pawg'), 7),
#  (('thoob', 'zej', 'thoob', 'zos'), 7),
#  (('muaj', 'kuab', 'muaj', 'tshuaj'), 7),
#  (('tsi', 'moog', 'tsi', 'lug'), 7),
#  (('tig', 'mus', 'tig', 'los'), 7),
#  (('ntau', 'tsaav', 'ntau', 'yaam'), 7),
#  (('khub', 'laj', 'khub', 'kam'), 7),
#  (('hmoob', 'roj', 'hmoob', 'ntshav'), 7),
#  (('them', 'nuj', 'them', 'nqi'), 7),
#  (('kauv', 'tes', 'kauv', 'taw'), 7),
#  (('tswj', 'teb', 'tswj', 'chaw'), 7),
#  (('muab', 'nyiaj', 'muab', 'kub'), 7),
#  (('neeg', 'txheeb', 'neeg', 'ze'), 7),
#  (('nrog', 'niam', 'nrog', 'txiv'), 7),
#  (('tub', 'qoob', 'tub', 'loo'), 7),
#  (('koom', 'teb', 'koom', 'chaw'), 7),
#  (('txhua', 'yam', 'txhua', 'tsav'), 7),
#  (('ua', 'tub', 'ua', 'kiv'), 7),
#  (('lub', 'sab', 'lub', 'ntsws'), 7),
#  (('tu', 'ub', 'tu', 'no'), 7),
#  (('luag', 'teej', 'luag', 'tug'), 7),
#  (('muaj', 'caij', 'muaj', 'nyoog'), 7),
#  (('xaav', 'moog', 'xaav', 'lug'), 7),
#  (('siv', 'nyiaj', 'siv', 'txiaj'), 7),
#  (('ntsuag', 'teb', 'ntsuag', 'chaw'), 7),
#  (('puv', 'toj', 'puv', 'pes'), 7),
#  (('tiav', 'nkauj', 'tiav', 'nraug'), 7),
#  (('tsw', 'lwj', 'tsw', 'kas'), 7),
#  (('kev', 'tshaib', 'kev', 'nqhis'), 7),
#  (('hlub', 'kwv', 'hlub', 'tij'), 7),
#  (('ua', 'pag', 'ua', 'xau'), 7),
#  (('sib', 'cob', 'sib', 'qhia'), 7),
#  (('neeg', 'txwj', 'neeg', 'laug'), 7),
#  (('rau', 'noj', 'rau', 'haus'), 7),
#  (('paub', 'txhij', 'paub', 'txhua'), 7),
#  (('muaj', 'koob', 'muaj', 'meej'), 7),
#  (('sib', 'txib', 'sib', 'hu'), 7),
#  (('tsis', 'ciaj', 'tsis', 'tuag'), 7),
#  (('noob', 'qoob', 'noob', 'loo'), 7),
#  (('qe', 'tooj', 'qe', 'hlau'), 7),
#  (('ntxhais', 'nom', 'ntxhais', 'tswv'), 7),
#  (('tawm', 'ntsej', 'tawm', 'muag'), 7),
#  (('ua', 'ncaj', 'ua', 'ncees'), 7),
#  (('nws', 'pog', 'nws', 'yawg'), 7),
#  (('lub', 'siab', 'lub', 'plawv'), 7),
#  (('nram', 'ntej', 'nram', 'qab'), 7),
#  (('kaum', 'vaj', 'kaum', 'tsev'), 7),
#  (('tej', 'tub', 'tej', 'kiv'), 7),
#  (('yus', 'noj', 'yus', 'haus'), 7),
#  (('ua', 'dlev', 'ua', 'npua'), 7),
#  (('qav', 'nom', 'qav', 'tswv'), 7),
#  (('tau', 'ntau', 'tau', 'tsawg'), 7),
#  (('muaj', 'tub', 'muaj', 'kiv'), 7),
#  (('muaj', 'qib', 'muaj', 'duas'), 6),
#  (('yas', 'kev', 'yas', 'ncua'), 6),
#  (('paub', 'dab', 'paub', 'qhua'), 6),
#  (('ntau', 'hnub', 'ntau', 'hmo'), 6),
#  (('tau', 'khawm', 'tau', 'puag'), 6),
#  (('lub', 'mob', 'lub', 'aws'), 6),
#  (('kho', 'teb', 'kho', 'chaw'), 6),
#  (('muaj', 'sab', 'muaj', 'ntsws'), 6),
#  (('nyob', 'deb', 'nyob', 'ze'), 6),
#  (('rooj', 'tshoob', 'rooj', 'kos'), 6),
#  (('ywj', 'faab', 'ywj', 'fwj'), 6),
#  (('zoo', 'noj', 'zoo', 'haus'), 6),
#  (('kev', 'ncaj', 'kev', 'ncees'), 6),
#  (('txaus', 'siab', 'txaus', 'ntsws'), 6),
#  (('tau', 'niam', 'tau', 'txiv'), 6),
#  (('kaus', 'tauj', 'kaus', 'nqeeb'), 6),
#  (('luag', 'kwv', 'luag', 'tij'), 6),
#  (('tu', 'vaaj', 'tu', 'tsev'), 6),
#  (('pub', 'qaib', 'pub', 'npua'), 6),
#  (('ua', 'tsuv', 'ua', 'rog'), 6),
#  (('txiv', 'maab', 'txiv', 'ntoo'), 6),
#  (('ntiv', 'tes', 'ntiv', 'taw'), 6),
#  (('nqaum', 'paj', 'nqaum', 'nruas'), 6),
#  (('sib', 'cav', 'sib', 'hais'), 6),
#  (('qub', 'phooj', 'qub', 'ywg'), 6),
#  (('pluag', 'noj', 'pluag', 'haus'), 6),
#  (('zov', 'vaj', 'zov', 'tsev'), 6),
#  (('kev', 'pleeg', 'kev', 'yi'), 6),
#  (('plig', 'nyiaj', 'plig', 'kub'), 6),
#  (('pab', 'kwv', 'pab', 'tij'), 6),
#  (('rau', 'kwv', 'rau', 'tij'), 6),
#  (('tsis', 'qab', 'tsis', 'tsuag'), 6),
#  (('nrog', 'liab', 'nrog', 'cuam'), 6),
#  (('dej', 'liab', 'dej', 'ntsuab'), 6),
#  (('tsis', 'ruaj', 'tsis', 'khov'), 6),
#  (('uas', 'pab', 'uas', 'pawg'), 6),
#  (('peb', 'noj', 'peb', 'haus'), 6),
#  (('tej', 'liaj', 'tej', 'teb'), 6),
#  (('ib', 'sij', 'ib', 'lwm'), 6),
#  (('sis', 'caav', 'sis', 'tshe'), 6),
#  (('fwm', 'nom', 'fwm', 'tswv'), 6),
#  (('noj', 'siav', 'noj', 'zog'), 6),
#  (('tau', 'vaj', 'tau', 'tsev'), 6),
#  (('hnab', 'ris', 'hnab', 'tsho'), 6),
#  (('teev', 'dab', 'teev', 'qhua'), 6),
#  (('dag', 'mab', 'dag', 'suav'), 6),
#  (('ntsim', 'siab', 'ntsim', 'plawv'), 6),
#  (('haav', 'zoov', 'haav', 'tsuag'), 6),
#  (('pam', 'neej', 'pam', 'dab'), 6),
#  (('pob', 'zeb', 'pob', 'ca'), 6),
#  (('kev', 'ab', 'kev', 'khwv'), 6),
#  (('me', 'nas', 'me', 'noog'), 6),
#  (('tej', 'ub', 'tej', 'no'), 6),
#  (('tag', 'hnub', 'tag', 'hmo'), 6),
#  (('fwm', 'niam', 'fwm', 'txiv'), 6),
#  (('saib', 'kwv', 'saib', 'tij'), 6),
#  (('tas', 'siab', 'tas', 'ntsws'), 6),
#  (('tus', 'kwv', 'tus', 'tij'), 6),
#  (('koj', 'vaj', 'koj', 'tsev'), 6),
#  (('suab', 'quaj', 'suab', 'nyiav'), 6),
#  (('hau', 'teb', 'hau', 'chaw'), 6),
#  (('xab', 'nom', 'xab', 'tswv'), 6),
#  (('rau', 'roj', 'rau', 'ntsev'), 6),
#  (('tsis', 'paub', 'tsis', 'hnov'), 6),
#  (('xaus', 'tshoob', 'xaus', 'kos'), 6),
#  (('muag', 'yeeb', 'muag', 'tshuaj'), 6),
#  (('mob', 'ub', 'mob', 'no'), 6),
#  (('huv', 'vaaj', 'huv', 'tsev'), 6),
#  (('raug', 'riam', 'raug', 'phom'), 6),
#  (('muaj', 'kab', 'muaj', 'kev'), 6),
#  (('muaj', 'riam', 'muaj', 'phom'), 6),
#  (('ntaiv', 'hnub', 'ntaiv', 'hli'), 6),
#  (('tos', 'noj', 'tos', 'haus'), 6),
#  (('ciam', 'liaj', 'ciam', 'av'), 6),
#  (('muaj', 'mob', 'muaj', 'tuag'), 6),
#  (('muas', 'noj', 'muas', 'haus'), 6),
#  (('yam', 'zoo', 'yam', 'phem'), 6),
#  (('haus', 'yeeb', 'haus', 'tshuaj'), 6),
#  (('khuam', 'tes', 'khuam', 'taw'), 6),
#  (('neeg', 'lwj', 'neeg', 'liam'), 6),
#  (('rau', 'thuv', 'rau', 'txim'), 6),
#  (('coj', 'noj', 'coj', 'haus'), 6),
#  (('nto', 'koob', 'nto', 'moo'), 6),
#  (('pom', 'dhuav', 'pom', 'txaus'), 6),
#  (('ua', 'phem', 'ua', 'qas'), 6),
#  (('noob', 'neej', 'noob', 'tsav'), 6),
#  (('txis', 'tshoob', 'txis', 'kos'), 6),
#  (('nws', 'pab', 'nws', 'pawg'), 6),
#  (('paum', 'nyuj', 'paum', 'twm'), 6),
#  (('vaj', 'loj', 'vaj', 'me'), 5),
#  (('yaug', 'ncauj', 'yaug', 'lo'), 5),
#  (('qhua', 'num', 'qhua', 'tswv'), 5),
#  (('yuav', 'nom', 'yuav', 'tswv'), 5),
#  (('yus', 'pog', 'yus', 'yawg'), 5),
#  (('peb', 'teb', 'peb', 'chaw'), 5),
#  (('yus', 'zej', 'yus', 'zos'), 5),
#  (('tej', 'pab', 'tej', 'pawg'), 5),
#  (('kev', 'caub', 'kev', 'chim'), 5),
#  (('koom', 'roj', 'koom', 'ntshav'), 5),
#  (('muaj', 'dag', 'muaj', 'zog'), 5),
#  (('xu', 'doj', 'xu', 'das'), 5),
#  (('qhov', 'ub', 'qhov', 'nuav'), 5),
#  (('muaj', 'txheeb', 'muaj', 'ze'), 5),
#  (('hauv', 'ntaub', 'hauv', 'ntawv'), 5),
#  (('paj', 'hmab', 'paj', 'ntoo'), 5),
#  (('zoo', 'kwv', 'zoo', 'tij'), 5),
#  (('txog', 'ub', 'txog', 'no'), 5),
#  (('sib', 'hlub', 'sib', 'tshua'), 5),
#  (('coob', 'leej', 'coob', 'tug'), 5),
#  (('qab', 'roob', 'qab', 'hav'), 5),
#  (('tuag', 'dawb', 'tuag', 'do'), 5),
#  (('nyiag', 'noj', 'nyiag', 'haus'), 5),
#  (('ua', 'zej', 'ua', 'zos'), 5),
#  (('yoo', 'tshaib', 'yoo', 'nqhis'), 5),
#  (('neeg', 'nom', 'neeg', 'tswv'), 5),
#  (('coj', 'teb', 'coj', 'chaw'), 5),
#  (('tsi', 'tag', 'tsi', 'kawg'), 5),
#  (('qee', 'leej', 'qee', 'tug'), 5),
#  (('ntau', 'niaj', 'ntau', 'xyoo'), 5),
#  (('kev', 'quaj', 'kev', 'nyiav'), 5),
#  (('chaw', 'txib', 'chaw', 'khaiv'), 5),
#  (('teg', 'dlej', 'teg', 'num'), 5),
#  (('noj', 'txhij', 'noj', 'txhua'), 5),
#  (('yus', 'pab', 'yus', 'pawg'), 5),
#  (('ntau', 'leej', 'ntau', 'tug'), 5),
#  (('lawv', 'teb', 'lawv', 'chaw'), 5),
#  (('kawg', 'paus', 'kawg', 'ntsis'), 5),
#  (('kuv', 'kwv', 'kuv', 'tij'), 5),
#  (('sib', 'txhawb', 'sib', 'pab'), 5),
#  (('puas', 'tsuaj', 'puas', 'ntsoog'), 5),
#  (('tej', 'zaub', 'tej', 'mov'), 5),
#  (('ua', 'dlaab', 'ua', 'qhua'), 5),
#  (('paub', 'qab', 'paub', 'hauv'), 5),
#  (('muab', 'dej', 'muab', 'cawv'), 5),
#  (('pauv', 'noj', 'pauv', 'haus'), 5),
#  (('tawg', 'teb', 'tawg', 'chaw'), 5),
#  (('muaj', 'nam', 'muaj', 'txiv'), 5),
#  (('hloov', 'mus', 'hloov', 'los'), 5),
#  (('dhia', 'ciaj', 'dhia', 'tuag'), 5),
#  (('chaw', 'caub', 'chaw', 'chim'), 5),
#  (('yuav', 'ub', 'yuav', 'no'), 5),
#  (('txuj', 'kev', 'txuj', 'cai'), 5),
#  (('ib', 'teb', 'ib', 'chaw'), 5),
#  (('ntug', 'zej', 'ntug', 'zos'), 5),
#  (('yuav', 'mab', 'yuav', 'suav'), 5),
#  (('kev', 'txob', 'kev', 'txhawj'), 5),
#  (('ib', 'txheej', 'ib', 'tis'), 5),
#  (('ke', 'tes', 'ke', 'taw'), 5),
#  (('siv', 'qeej', 'siv', 'nruas'), 5),
#  (('suab', 'qeej', 'suab', 'nruas'), 5),
#  (('ua', 'kub', 'ua', 'ntxhov'), 5),
#  (('koj', 'nam', 'koj', 'txiv'), 5),
#  (('dim', 'dawb', 'dim', 'do'), 5),
#  (('yuav', 'cem', 'yuav', 'thuam'), 5),
#  (('rau', 'tes', 'rau', 'taw'), 5),
#  (('tub', 'tes', 'tub', 'taw'), 5),
#  (('saib', 'dab', 'saib', 'qhua'), 5),
#  (('dab', 'pog', 'dab', 'yawg'), 5),
#  (('kub', 'tes', 'kub', 'taw'), 5),
#  (('ntsuag', 'xyoob', 'ntsuag', 'ntoo'), 5),
#  (('hloov', 'siab', 'hloov', 'ntsws'), 5),
#  (('tsis', 'ntsib', 'tsis', 'pom'), 5),
#  (('tej', 'neej', 'tej', 'tsav'), 5),
#  (('kev', 'zej', 'kev', 'zos'), 5),
#  (('pov', 'hwm', 'pov', 'yoom'), 5),
#  (('muaj', 'kiab', 'muaj', 'khw'), 5),
#  (('muaj', 'nuj', 'muaj', 'nqi'), 5),
#  (('yus', 'txawj', 'yus', 'ntse'), 5),
#  (('koj', 'puj', 'koj', 'yawm'), 5),
#  (('tug', 'yeej', 'tug', 'swb'), 5),
#  (('noob', 'xyoob', 'noob', 'ntoo'), 5),
#  (('muaj', 'tshoob', 'muaj', 'kos'), 5),
#  (('tej', 'neej', 'tej', 'tsa'), 5),
#  (('ua', 'zoo', 'ua', 'phem'), 5),
#  (('do', 'quav', 'do', 'zis'), 5),
#  (('peb', 'teej', 'peb', 'tug'), 5),
#  (('tsev', 'mob', 'tsev', 'tuag'), 5),
#  (('ua', 'nrw', 'ua', 'nrees'), 5),
#  (('nqi', 'tshoob', 'nqi', 'kos'), 5),
#  (('kho', 'vaj', 'kho', 'tsev'), 5),
#  (('qhuas', 'qab', 'qhuas', 'tsaus'), 5),
#  (('ntsis', 'riam', 'ntsis', 'phom'), 5),
#  (('qhov', 'zeb', 'qhov', 'tsua'), 5),
#  (('qee', 'leej', 'qee', 'tus'), 5),
#  (('tsawg', 'pab', 'tsawg', 'pawg'), 5),
#  (('peb', 'kwv', 'peb', 'tij'), 5),
#  (('tsis', 'loj', 'tsis', 'siab'), 5),
#  (('nws', 'poj', 'nws', 'yawm'), 5),
#  (('noob', 'tsiaj', 'noob', 'txhu'), 5),
#  (('lus', 'iab', 'lus', 'daw'), 5),
#  (('mloog', 'mus', 'mloog', 'los'), 5),
#  (('txau', 'noj', 'txau', 'haus'), 5),
#  (('tus', 'ntxhais', 'tus', 'vauv'), 5),
#  (('pav', 'tes', 'pav', 'taw'), 5),
#  (('nraav', 'noj', 'nraav', 'haus'), 5),
#  (('tua', 'qaib', 'tua', 'npua'), 5),
#  (('tuaj', 'saib', 'tuaj', 'xyuas'), 5),
#  (('lus', 'dog', 'lus', 'dig'), 4),
#  (('noob', 'ntaub', 'noob', 'ntawv'), 4),
#  (('sib', 'hais', 'sib', 'kho'), 4),
#  (('uas', 'noj', 'uas', 'haus'), 4),
#  (('tsi', 'paub', 'tsi', 'pom'), 4),
#  (('ua', 'qoob', 'ua', 'loo'), 4),
#  (('tshav', 'noj', 'tshav', 'haus'), 4),
#  (('haus', 'zej', 'haus', 'zos'), 4),
#  (('caag', 'maab', 'caag', 'ntoo'), 4),
#  (('me', 'roj', 'me', 'ntshav'), 4),
#  (('tam', 'niam', 'tam', 'txiv'), 4),
#  (('xeeb', 'zeej', 'xeeb', 'ntxwv'), 4),
#  (('nkaum', 'ub', 'nkaum', 'no'), 4),
#  (('ua', 'khab', 'ua', 'khuav'), 4),
#  (('raws', 'caij', 'raws', 'nyoog'), 4),
#  (('cam', 'ub', 'cam', 'no'), 4),
#  (('siv', 'caij', 'siv', 'nyoog'), 4),
#  (('nrog', 'pom', 'nrog', 'paub'), 4),
#  (('sib', 'tham', 'sib', 'kho'), 4),
#  (('npuas', 'ncauj', 'npuas', 'ntswg'), 4),
#  (('saib', 'ntsej', 'saib', 'muag'), 4),
#  (('moob', 'neej', 'moob', 'tsaav'), 4),
#  (('khuj', 'noj', 'khuj', 'haus'), 4),
#  (('yog', 'plaub', 'yog', 'ntug'), 4),
#  (('tej', 'ntsuj', 'tej', 'plig'), 4),
#  (('yus', 'dab', 'yus', 'qhua'), 4),
#  (('tej', 'xyoob', 'tej', 'ntoo'), 4),
#  (('sib', 'hlub', 'sib', 'haum'), 4),
#  (('puv', 'ntuj', 'puv', 'teb'), 4),
#  (('cuab', 'ub', 'cuab', 'no'), 4),
#  (('mag', 'cuab', 'mag', 'khi'), 4),
#  (('tau', 'nyiaj', 'tau', 'txiaj'), 4),
#  (('ntsuag', 'nom', 'ntsuag', 'tswv'), 4),
#  (('lug', 'coj', 'lug', 'ua'), 4),
#  (('xaiv', 'nom', 'xaiv', 'tswv'), 4),
#  (('vij', 'dab', 'vij', 'npog'), 4),
#  (('zoo', 'neej', 'zoo', 'tsav'), 4),
#  (('laub', 'dej', 'laub', 'cawv'), 4),
#  (('lus', 'muag', 'lus', 'mos'), 4),
#  (('tsim', 'teev', 'tsim', 'tsi'), 4),
#  (('tej', 'sab', 'tej', 'ntsws'), 4),
#  (('hais', 'lwj', 'hais', 'liam'), 4),
#  (('lus', 'ntxhib', 'lus', 'ntxho'), 4),
#  (('ua', 'kub', 'ua', 'heev'), 4),
#  (('sib', 'txhawb', 'sib', 'nqa'), 4),
#  (('nyuj', 'ciab', 'nyuj', 'ncau'), 4),
#  (('noog', 'ub', 'noog', 'no'), 4),
#  (('koom', 'pog', 'koom', 'yawg'), 4),
#  (('sib', 'tog', 'sib', 'txeeb'), 4),
#  (('muag', 'nom', 'muag', 'tswv'), 4),
#  (('rua', 'ub', 'rua', 'nuav'), 4),
#  (('siab', 'mos', 'siab', 'muag'), 4),
#  (('hwm', 'nom', 'hwm', 'tswv'), 4),
#  (('zoo', 'niam', 'zoo', 'txiv'), 4),
#  (('hais', 'zoo', 'hais', 'phem'), 4),
#  (('cab', 'nyuj', 'cab', 'twm'), 4),
#  (('luag', 'tes', 'luag', 'taw'), 4),
#  (('qhov', 'pim', 'qhov', 'qau'), 4),
#  (('tus', 'mab', 'tus', 'suav'), 4),
#  (('ua', 'voj', 'ua', 'viag'), 4),
#  (('tug', 'ub', 'tug', 'no'), 4),
#  (('nraug', 'kev', 'nraug', 'cai'), 4),
#  (('tav', 'ntuj', 'tav', 'teb'), 4),
#  (('nyob', 'ub', 'nyob', 'no'), 4),
#  (('nrog', 'mab', 'nrog', 'suav'), 4),
#  (('tau', 'neej', 'tau', 'tsav'), 4),
#  (('tsi', 'txheeb', 'tsi', 'ze'), 4),
#  (('txog', 'dej', 'txog', 'cawv'), 4),
#  (('txiv', 'hlob', 'txiv', 'yau'), 4),
#  (('hlab', 'liab', 'hlab', 'ntsuab'), 4),
#  (('tig', 'ntsej', 'tig', 'muag'), 4),
#  (('noj', 'tshoob', 'noj', 'kos'), 4),
#  (('kaum', 'vaaj', 'kaum', 'tsev'), 4),
#  (('sib', 'nyiam', 'sib', 'hlub'), 4),
#  (('luag', 'zej', 'luag', 'zos'), 4),
#  (('nqi', 'vaj', 'nqi', 'tsev'), 4),
#  (('tshuav', 'kwv', 'tshuav', 'tij'), 4),
#  (('cais', 'paab', 'cais', 'pawg'), 4),
#  (('qhov', 'tseeb', 'qhov', 'cuav'), 4),
#  (('tsis', 'yog', 'tsis', 'raug'), 4),
#  (('khi', 'tes', 'khi', 'taw'), 4),
#  (('kuv', 'vaj', 'kuv', 'tsev'), 4),
#  (('tuag', 'tes', 'tuag', 'taw'), 4),
#  (('qhov', 'loj', 'qhov', 'me'), 4),
#  (('phov', 'ub', 'phov', 'no'), 4),
#  (('tej', 'rooj', 'tej', 'tog'), 4),
#  (('muaj', 'kev', 'muaj', 'cai'), 4),
#  (('hais', 'dog', 'hais', 'dig'), 4),
#  (('sau', 'qoob', 'sau', 'loo'), 4),
#  (('ua', 'pawg', 'ua', 'lug'), 4),
#  (('tis', 'neej', 'tis', 'tsav'), 4),
#  (('me', 'kwv', 'me', 'tij'), 4),
#  (('thov', 'nyiaj', 'thov', 'txiaj'), 4),
#  (('saib', 'qab', 'saib', 'hauv'), 4),
#  (('luag', 'pab', 'luag', 'pawg'), 4),
#  (('has', 'txhij', 'has', 'txhua'), 4),
#  (('me', 'xyoob', 'me', 'ntoo'), 4),
#  (('paub', 'qaab', 'paub', 'hau'), 4),
#  (('xav', 'pom', 'xav', 'paub'), 4),
#  (('sab', 'khwb', 'sab', 'ntxeev'), 4),
#  (('coj', 'dab', 'coj', 'qhua'), 4),
#  (('cem', 'lwj', 'cem', 'liam'), 4),
#  (('ua', 'dab', 'ua', 'tsov'), 4),
#  (('cov', 'phooj', 'cov', 'ywg'), 4),
#  (('tej', 'puj', 'tej', 'yawm'), 4),
#  (('uas', 'nom', 'uas', 'tswv'), 4),
#  (('xaiv', 'txij', 'xaiv', 'nkawm'), 4),
#  (('muag', 'vaj', 'muag', 'tsev'), 4),
#  (('mus', 'cuab', 'mus', 'khi'), 4),
#  (('lug', 'ntxhib', 'lug', 'ntxho'), 4),
#  (('tau', 'ub', 'tau', 'no'), 4),
#  (('luag', 'rooj', 'luag', 'ntsa'), 4),
#  (('npaj', 'riam', 'npaj', 'phom'), 4),
#  (('dab', 'tooj', 'dab', 'hlau'), 4),
#  (('tuav', 'laj', 'tuav', 'kam'), 4),
#  (('muaj', 'qab', 'muaj', 'quag'), 4),
#  (('qab', 'zeb', 'qab', 'ca'), 4),
#  (('nqaij', 'nyuj', 'nqaij', 'twm'), 4),
#  (('poob', 'koob', 'poob', 'npe'), 4),
#  (('tug', 'kwv', 'tug', 'tij'), 4),
#  (('nkaum', 'tes', 'nkaum', 'taw'), 4),
#  (('mus', 'saib', 'mus', 'xyuas'), 4),
#  (('tom', 'vaaj', 'tom', 'tsev'), 4),
#  (('ua', 'tsov', 'ua', 'plis'), 4),
#  (('sib', 'koom', 'sib', 'pab'), 4),
#  (('tau', 'koob', 'tau', 'hmoov'), 4),
#  (('roob', 'nqeeb', 'roob', 'tauj'), 4),
#  (('npe', 'nom', 'npe', 'tswv'), 4),
#  (('hais', 'kwv', 'hais', 'tij'), 4),
#  ...]

# %% [markdown]
# For each elaborate expression in all_elabs, have 91.39% chance of putting in the training set and 9% chance of putting in the val/test set

# %%
import random
random.seed(12)

num_datasets = 3
# these sets have EEs as elements
train_sets, valtest_sets = [set([]) for _ in range(num_datasets)], [set([]) for _ in range(num_datasets)]
train_count, valtest_count = [0]*num_datasets, [0]*num_datasets

for i in range(num_datasets):
    for elab, count in all_elabs.items():
        if random.random() > 0.9139:
            valtest_sets[i].add(elab)
            valtest_count[i] += count
        else:
            train_sets[i].add(elab)
            train_count[i] += count
            
print(valtest_count)
print(train_count)
# Out:
# [2707, 2117, 2661]
# [21867, 22457, 21913]

# %%
print(valtest_count)
# Out:
# [2707, 2117, 2661]

# %%
random.seed(12)

def find_EEs(sentence, tag):
    EEs = []
    assert len(sentence) == len(tag)
    for token, a_tag in zip(sentence, tag):
        if a_tag == 'B':
            EEs.append([token])
        elif a_tag == 'I':
            EEs[-1].append(token)
    return EEs


# these sets have sentence id as elements
train_splits, val_splits, test_splits = [set([]) for _ in range(num_datasets)], [set([]) for _ in range(num_datasets)], [set([]) for _ in range(num_datasets)]

for fn in glob.glob(os.path.join(DATA_FOLDER, '*.conll')):
    i = os.path.basename(fn).split('.')[0].split('-')[1]
    sentences, tags = readin_one_file(fn, separate_comma=True, convert_to_idx=False)
    for j, (s, t) in enumerate(zip(sentences, tags)):
        identifier = f'{i}-{j:04d}'
        if len(s) > 0:
            EEs_in_this_sentence = find_EEs(s, t)

            for n in range(num_datasets):
                if len(EEs_in_this_sentence) == 0: # this is a negative sentence
                    if random.random() > 0.9124:
                        if random.random() >= 0.5:
                            val_splits[n].add(identifier)
                        else:
                            test_splits[n].add(identifier)
                    else:
                        train_splits[n].add(identifier)
                else:  # this is a positive sentence
                    if all(tuple(map(i2w.__getitem__, ee)) in valtest_sets[n] for ee in EEs_in_this_sentence):
#                         print('add')
                        if random.random() >= 0.5:
                            val_splits[n].add(identifier)
                        else:
                            test_splits[n].add(identifier)
                    else:
                        train_splits[n].add(identifier)
                    
print([len(train) for train in train_splits])
print([len(val) for val in val_splits])
print([len(test) for test in test_splits])
# Out:
# [675654, 675402, 675177]
# [32298, 32593, 32537]
# [32516, 32473, 32754]

# %%
random.seed(12)
for n in range(num_datasets):
    # Partition the grouped splits into 50% swap and 50% keep
    train_elabs = list(train_sets[n])
    valtest_elabs = list(valtest_sets[n])
    random.shuffle(train_elabs)
    random.shuffle(valtest_elabs)

    train_elabs_swap = train_elabs[:len(train_elabs)//2]
    train_elabs_keep = train_elabs[len(train_elabs)//2:]
    valtest_elabs_swap = valtest_elabs[:len(valtest_elabs)//2]
    valtest_elabs_keep = valtest_elabs[len(valtest_elabs)//2:]
    
    split = {'train': train_splits[n], 'val': val_splits[n], 'test': test_splits[n],
            'train_elabs': train_sets[n], 'valtest_elabs': valtest_sets[n],
            'train_elabs_swap': train_elabs_swap,
            'train_elabs_keep': train_elabs_keep,
            'valtest_elabs_swap': valtest_elabs_swap,
            'valtest_elabs_keep': valtest_elabs_keep,
            }
    # uncomment to save
    torch.save(split, f"../data/hmong/split_grouped_lid_{n+1}.pth")

# %%
i2l
# Out:
# ['PAD', 'O', 'I', 'B']

# %% [markdown]
# What's the least frequent word that also occurs in an extracted EE?
# --
# some words occur 3, 5, 6, 7 times in the corpus, but using the min count=10 cut off should still be fine.

# %%
df = pd.read_csv("../data/hmong/extracted_elabs/elabs_extracted.csv", sep=',', quoting=1)

# %%
syllables = set([])
syllables = syllables.union(df['word1'].tolist()).union(df['word2'].tolist()).union(df['word4'].tolist())
syllables.remove('ntusag')

# %%
sorted((all_words[syl], syl) for syl in syllables)
# Out:
# [(3, 'chiaj'),
#  (3, 'viag'),
#  (5, 'dloj'),
#  (5, 'nqhe'),
#  (6, 'dhiab'),
#  (7, 'ncis'),
#  (8, 'doj'),
#  (10, 'ncaab'),
#  (11, 'hnias'),
#  (11, 'txee'),
#  (12, 'txoo'),
#  (13, 'thaws'),
#  (15, 'nkuas'),
#  (15, 'nrus'),
#  (15, 'ntxho'),
#  (16, 'ncoj'),
#  (16, 'nplo'),
#  (16, 'vuam'),
#  (17, 'ndlog'),
#  (17, 'npu'),
#  (17, 'ntxhis'),
#  (17, 'qag'),
#  (18, 'nrhaav'),
#  (19, 'dlaus'),
#  (19, 'mij'),
#  (20, 'chab'),
#  (20, 'daub'),
#  (20, 'npooj'),
#  (20, 'pwj'),
#  (21, 'nrhaw'),
#  (21, 'ntxua'),
#  (21, 'yoom'),
#  (22, 'nkib'),
#  (23, 'sos'),
#  (24, 'caa'),
#  (24, 'hlev'),
#  (24, 'plaag'),
#  (24, 'vaus'),
#  (24, 'zuas'),
#  (25, 'yoos'),
#  (27, 'npws'),
#  (28, 'ntsoj'),
#  (29, 'nrw'),
#  (29, 'tshuv'),
#  (30, 'ncawg'),
#  (30, 'ntaim'),
#  (33, 'npaim'),
#  (33, 'vis'),
#  (34, 'nkhib'),
#  (36, 'dlawm'),
#  (36, 'ntee'),
#  (36, 'plawm'),
#  (36, 'tshoom'),
#  (37, 'hlas'),
#  (37, 'hnyuv'),
#  (39, 'ntswb'),
#  (40, 'nqaum'),
#  (40, 'qij'),
#  (42, 'thum'),
#  (42, 'txham'),
#  (43, 'ndlav'),
#  (43, 'pleeg'),
#  (45, 'ruj'),
#  (46, 'plhaw'),
#  (47, 'nplij'),
#  (47, 'ntsauv'),
#  (48, 'txhiam'),
#  (49, 'khaiv'),
#  (49, 'plas'),
#  (50, 'leev'),
#  (50, 'ncas'),
#  (50, 'swv'),
#  (51, 'tsws'),
#  (51, 'txhoov'),
#  (52, 'muv'),
#  (52, 'nris'),
#  (52, 'qej'),
#  (53, 'ntas'),
#  (56, 'nphau'),
#  (56, 'tshaum'),
#  (56, 'yais'),
#  (57, 'kug'),
#  (57, 'nrees'),
#  (57, 'phaib'),
#  (61, 'coos'),
#  (62, 'vuab'),
#  (63, 'fuas'),
#  (63, 'mlom'),
#  (64, 'cis'),
#  (65, 'dhiav'),
#  (66, 'txoog'),
#  (66, 'yaag'),
#  (67, 'qoj'),
#  (69, 'hloob'),
#  (70, 'sem'),
#  (71, 'phaub'),
#  (72, 'ntshaa'),
#  (72, 'ntxhuav'),
#  (72, 'txeem'),
#  (72, 'txu'),
#  (72, 'xawb'),
#  (75, 'ntxo'),
#  (75, 'voog'),
#  (76, 'nraav'),
#  (76, 'txhaus'),
#  (77, 'nqee'),
#  (77, 'roos'),
#  (78, 'ncha'),
#  (78, 'txeej'),
#  (80, 'xeej'),
#  (80, 'xiav'),
#  (81, 'doog'),
#  (81, 'hmuv'),
#  (83, 'dlog'),
#  (83, 'xyaws'),
#  (84, 'hlauv'),
#  (86, 'ntaaj'),
#  (86, 'nywj'),
#  (87, 'tshom'),
#  (89, 'cheb'),
#  (89, 'yaug'),
#  (91, 'poo'),
#  (92, 'pheem'),
#  (92, 'sw'),
#  (95, 'aus'),
#  (95, 'ntxia'),
#  (97, 'ntoj'),
#  (97, 'yi'),
#  (99, 'fij'),
#  (100, 'nraj'),
#  (101, 'nquam'),
#  (102, 'lib'),
#  (102, 'ntsub'),
#  (102, 'ntxhuv'),
#  (102, 'thuv'),
#  (103, 'qig'),
#  (104, 'dee'),
#  (104, 'nyiav'),
#  (104, 'phaab'),
#  (104, 'quag'),
#  (105, 'maaj'),
#  (105, 'txoob'),
#  (106, 'fee'),
#  (108, 'khuab'),
#  (110, 'qai'),
#  (111, 'com'),
#  (112, 'qeg'),
#  (113, 'nteeg'),
#  (113, 'qhe'),
#  (114, 'ntxhib'),
#  (114, 'vej'),
#  (115, 'luab'),
#  (115, 'npiab'),
#  (116, 'dheev'),
#  (116, 'naag'),
#  (118, 'faab'),
#  (118, 'khauj'),
#  (118, 'phiv'),
#  (120, 'xaws'),
#  (123, 'hmov'),
#  (125, 'lawg'),
#  (125, 'nog'),
#  (125, 'nquab'),
#  (127, 'tshooj'),
#  (128, 'ntsaum'),
#  (129, 'nchav'),
#  (130, 'naab'),
#  (130, 'rwj'),
#  (131, 'nplig'),
#  (132, 'voj'),
#  (132, 'xais'),
#  (133, 'khaw'),
#  (133, 'npuj'),
#  (134, 'pheev'),
#  (135, 'plhis'),
#  (136, 'dlig'),
#  (137, 'das'),
#  (137, 'khuav'),
#  (137, 'ntuv'),
#  (139, 'caab'),
#  (139, 'roog'),
#  (140, 'maab'),
#  (141, 'nkaub'),
#  (142, 'nceeg'),
#  (144, 'dawj'),
#  (144, 'sev'),
#  (144, 'tshis'),
#  (145, 'taij'),
#  (145, 'xuam'),
#  (146, 'yoj'),
#  (147, 'txhu'),
#  (148, 'dam'),
#  (148, 'hawv'),
#  (149, 'teej'),
#  (151, 'tseb'),
#  (152, 'nrad'),
#  (153, 'daw'),
#  (153, 'txis'),
#  (153, 'xya'),
#  (154, 'cos'),
#  (154, 'vov'),
#  (155, 'raj'),
#  (156, 'nraab'),
#  (156, 'tshais'),
#  (156, 'xau'),
#  (156, 'yej'),
#  (159, 'chawj'),
#  (159, 'nqug'),
#  (159, 'ped'),
#  (160, 'neev'),
#  (160, 'ntwg'),
#  (162, 'xwj'),
#  (164, 'thawm'),
#  (168, 'hnia'),
#  (168, 'ncau'),
#  (168, 'ntxi'),
#  (169, 'hlaus'),
#  (171, 'xyab'),
#  (174, 'npuag'),
#  (174, 'plees'),
#  (175, 'da'),
#  (176, 'ntshaav'),
#  (176, 'plaab'),
#  (176, 'pluas'),
#  (177, 'pag'),
#  (178, 'nias'),
#  (179, 'daus'),
#  (179, 'nqhis'),
#  (181, 'tsham'),
#  (182, 'rag'),
#  (182, 'tshaav'),
#  (186, 'chua'),
#  (186, 'kaug'),
#  (187, 'kuaj'),
#  (190, 'ntsoog'),
#  (192, 'naav'),
#  (193, 'lwg'),
#  (193, 'txhuv'),
#  (193, 'zes'),
#  (198, 'ciab'),
#  (198, 'kiv'),
#  (198, 'lej'),
#  (198, 'txhuas'),
#  (200, 'diav'),
#  (200, 'hno'),
#  (202, 'phov'),
#  (203, 'ntaiv'),
#  (203, 'pluaj'),
#  (204, 'xiv'),
#  (213, 'kes'),
#  (213, 'khuj'),
#  (214, 'nqos'),
#  (215, 'npaws'),
#  (217, 'leem'),
#  (217, 'moov'),
#  (217, 'plhu'),
#  (218, 'dluab'),
#  (219, 'nrim'),
#  (219, 'ntoos'),
#  (220, 'ntawg'),
#  (221, 'kawv'),
#  (221, 'tauv'),
#  (223, 'laig'),
#  (224, 'dlaav'),
#  (228, 'nthe'),
#  (228, 'qeeb'),
#  (230, 'dawm'),
#  (230, 'ntub'),
#  (231, 'nplaum'),
#  (233, 'daum'),
#  (237, 'plis'),
#  (241, 'kuag'),
#  (242, 'nroj'),
#  (245, 'fim'),
#  (246, 'txhav'),
#  (250, 'qes'),
#  (251, 'txam'),
#  (252, 'lob'),
#  (254, 'khoo'),
#  (254, 'txus'),
#  (257, 'nkhaus'),
#  (258, 'txhis'),
#  (259, 'npuav'),
#  (260, 'tsawm'),
#  (260, 'yws'),
#  (261, 'ntab'),
#  (264, 'nta'),
#  (265, 'tshee'),
#  (265, 'txhab'),
#  (268, 'rhawv'),
#  (269, 'haav'),
#  (272, 'npuas'),
#  (273, 'kiab'),
#  (273, 'taum'),
#  (274, 'pluj'),
#  (275, 'qas'),
#  (276, 'hmos'),
#  (276, 'kaab'),
#  (276, 'ntsig'),
#  (278, 'nkees'),
#  (278, 'npuab'),
#  (279, 'ki'),
#  (279, 'txhoj'),
#  (282, 'hmab'),
#  (282, 'paim'),
#  (285, 'txiab'),
#  (288, 'keb'),
#  (288, 'nyeg'),
#  (292, 'nqeeb'),
#  (292, 'qoob'),
#  (293, 'hlab'),
#  (295, 'khau'),
#  (296, 'txaij'),
#  (297, 'nchuav'),
#  (298, 'xyaw'),
#  (299, 'cig'),
#  (299, 'xauv'),
#  (300, 'ciav'),
#  (300, 'dib'),
#  (301, 'ntuag'),
#  (304, 'nkoj'),
#  (304, 'ntxiab'),
#  (305, 'txov'),
#  (308, 'xu'),
#  (309, 'txig'),
#  (313, 'pha'),
#  (316, 'hai'),
#  (317, 'yaum'),
#  (318, 'plag'),
#  (319, 'nkaug'),
#  (320, 'txuag'),
#  (320, 'zeej'),
#  (323, 'dlha'),
#  (323, 'yoo'),
#  (325, 'txwj'),
#  (327, 'leg'),
#  (327, 'ntshaws'),
#  (328, 'khaum'),
#  (329, 'vij'),
#  (331, 'zis'),
#  (337, 'ntws'),
#  (337, 'tsog'),
#  (337, 'txag'),
#  (340, 'ntsa'),
#  (342, 'dhuav'),
#  (342, 'yos'),
#  (344, 'qees'),
#  (345, 'yas'),
#  (349, 'faus'),
#  (354, 'mi'),
#  (356, 'aav'),
#  (356, 'ncej'),
#  (356, 'tshe'),
#  (356, 'xis'),
#  (357, 'sua'),
#  (360, 'duav'),
#  (362, 'peem'),
#  (362, 'tsuv'),
#  (366, 'ntsev'),
#  (369, 'tsuaj'),
#  (370, 'haub'),
#  (370, 'khawm'),
#  (370, 'lem'),
#  (374, 'qaub'),
#  (374, 'vog'),
#  (375, 'kaws'),
#  (375, 'npoj'),
#  (376, 'txau'),
#  (379, 'nra'),
#  (384, 'txib'),
#  (388, 'ncuav'),
#  (389, 'vuag'),
#  (391, 'qias'),
#  (391, 'taj'),
#  (391, 'tum'),
#  (397, 'tsaav'),
#  (398, 'fwj'),
#  (406, 'mo'),
#  (407, 'tseev'),
#  (408, 'khab'),
#  (412, 'hniav'),
#  (418, 'paug'),
#  (421, 'txawb'),
#  (422, 'ntsw'),
#  (422, 'tsaws'),
#  (425, 'qav'),
#  (426, 'ntaj'),
#  (426, 'ntuas'),
#  (427, 'nqaj'),
#  (427, 'ntswg'),
#  (428, 'ntim'),
#  (429, 'khub'),
#  (430, 'npav'),
#  (432, 'dleb'),
#  (434, 'hneev'),
#  (436, 'khw'),
#  (436, 'nruj'),
#  (438, 'laub'),
#  (439, 'de'),
#  (439, 'dos'),
#  (445, 'ncua'),
#  (447, 'nruas'),
#  (447, 'ntsi'),
#  (448, 'chob'),
#  (448, 'raw'),
#  (453, 'mes'),
#  (453, 'ncaaj'),
#  (453, 'plam'),
#  (454, 'npab'),
#  (459, 'qws'),
#  (460, 'zuag'),
#  (465, 'kauv'),
#  (465, 'xaa'),
#  (467, 'khuam'),
#  (467, 'yias'),
#  (468, 'ntsuam'),
#  (477, 'fuab'),
#  (480, 'npog'),
#  (482, 'khaus'),
#  (484, 'khwb'),
#  (486, 'qos'),
#  (487, 'su'),
#  (490, 'ncaim'),
#  (504, 'cub'),
#  (504, 'kuab'),
#  (514, 'ntiv'),
#  (518, 'duas'),
#  (522, 'caav'),
#  (528, 'xyoob'),
#  (535, 'ntsuas'),
#  (537, 'fa'),
#  (539, 'mis'),
#  (540, 'nyas'),
#  (541, 'ntsws'),
#  (542, 'txua'),
#  (548, 'hnab'),
#  (549, 'ciam'),
#  (551, 'qis'),
#  (553, 'paaj'),
#  (554, 'xauj'),
#  (555, 'qib'),
#  (558, 'tsaj'),
#  (560, 'ntxhov'),
#  (566, 'thau'),
#  (574, 'nriav'),
#  (575, 'yoog'),
#  (576, 'qus'),
#  (583, 'cag'),
#  (589, 'moo'),
#  (591, 'tsom'),
#  (591, 'tswm'),
#  (592, 'nkuaj'),
#  (592, 'ntees'),
#  (595, 'hus'),
#  (597, 'nplua'),
#  (600, 'nkim'),
#  (602, 'nyoo'),
#  (603, 'txhij'),
#  (613, 'kaam'),
#  (616, 'liaj'),
#  (623, 'dlev'),
#  (623, 'tsau'),
#  (624, 'tauj'),
#  (628, 'nyav'),
#  (631, 'dai'),
#  (631, 'kaum'),
#  (631, 'khi'),
#  (631, 'yaaj'),
#  (635, 'tshaib'),
#  (636, 'seem'),
#  (637, 'ruaj'),
#  (640, 'caiv'),
#  (640, 'tiaj'),
#  (641, 'caub'),
#  (644, 'txo'),
#  (657, 'tsib'),
#  (658, 'pauj'),
#  (662, 'ywj'),
#  (664, 'thim'),
#  (670, 'xiam'),
#  (675, 'khaub'),
#  (684, 'du'),
#  (687, 'tod'),
#  (689, 'pav'),
#  (689, 'raus'),
#  (690, 'ntsuj'),
#  (691, 'hlawv'),
#  (693, 'nus'),
#  (695, 'yaig'),
#  (697, 'cim'),
#  (701, 'teem'),
#  (703, 'pliag'),
#  (709, 'zaaj'),
#  (714, 'ntxwv'),
#  (719, 'pa'),
#  (720, 'nkawm'),
#  (723, 'fawm'),
#  (725, 'nyag'),
#  (727, 'ntsim'),
#  (731, 'law'),
#  (741, 'peg'),
#  (742, 'mev'),
#  (749, 'phaum'),
#  (756, 'txav'),
#  (758, 'kov'),
#  (765, 'nrau'),
#  (765, 'qhev'),
#  (768, 'nag'),
#  (770, 'dog'),
#  (774, 'nees'),
#  (777, 'lawb'),
#  (785, 'nto'),
#  (786, 'phav'),
#  (787, 'qhuab'),
#  (788, 'plawv'),
#  (794, 'khawb'),
#  (796, 'vauv'),
#  (797, 'hle'),
#  (809, 'daj'),
#  (811, 'txhiab'),
#  (812, 'foob'),
#  (814, 'ntxeev'),
#  (817, 'dlej'),
#  (819, 'pua'),
#  (824, 'tsoo'),
#  (833, 'hla'),
#  (835, 'nrhav'),
#  (838, 'luv'),
#  (840, 'tsaus'),
#  (840, 'txhom'),
#  (843, 'dlaag'),
#  (843, 'txias'),
#  (844, 'xim'),
#  (846, 'xaus'),
#  (854, 'huam'),
#  (854, 'nroog'),
#  (856, 'phab'),
#  (860, 'fwm'),
#  (865, 'laib'),
#  (870, 'mab'),
#  (871, 'xib'),
#  (877, 'hlua'),
#  (878, 'tsob'),
#  (882, 'paum'),
#  (885, 'pam'),
#  (891, 'tawb'),
#  (893, 'ncu'),
#  (893, 'tsoob'),
#  (897, 'tsho'),
#  (902, 'txia'),
#  (904, 'pluag'),
#  (905, 'qaug'),
#  (905, 'txob'),
#  (911, 'zug'),
#  (913, 'dlhau'),
#  (913, 'khawv'),
#  (925, 'riam'),
#  (926, 'deev'),
#  (929, 'zej'),
#  (930, 'pe'),
#  (934, 'qeej'),
#  (937, 'rub'),
#  (937, 'zeem'),
#  (939, 'yij'),
#  (942, 'zais'),
#  (954, 'saab'),
#  (960, 'txuas'),
#  (984, 'lag'),
#  (985, 'fwv'),
#  (987, 'hmoov'),
#  (992, 'nrab'),
#  (992, 'tshawb'),
#  (997, 'khu'),
#  (1006, 'qe'),
#  (1007, 'hnav'),
#  (1007, 'lim'),
#  (1009, 'qau'),
#  (1017, 'cam'),
#  (1017, 'xeev'),
#  (1021, 'nti'),
#  (1024, 'cheem'),
#  (1024, 'roj'),
#  (1048, 'ntsiab'),
#  (1057, 'kwm'),
#  (1062, 'dlawb'),
#  (1065, 'lav'),
#  (1070, 'qee'),
#  (1074, 'pim'),
#  (1078, 'cuam'),
#  (1083, 'hlis'),
#  (1085, 'ntsuag'),
#  (1085, 'ti'),
#  (1088, 'lu'),
#  (1088, 'sob'),
#  (1098, 'tsiv'),
#  (1099, 'twj'),
#  (1100, 'paus'),
#  (1107, 'tshav'),
#  (1115, 'foom'),
#  (1123, 'tsawv'),
#  (1128, 'iab'),
#  (1128, 'rhuav'),
#  (1131, 'keeb'),
#  (1131, 'tsuag'),
#  (1139, 'cuav'),
#  (1145, 'dig'),
#  (1148, 'phaj'),
#  (1161, 'kaus'),
#  (1161, 'lig'),
#  (1178, 'puv'),
#  (1187, 'hwm'),
#  (1188, 'nplooj'),
#  (1192, 'qaum'),
#  (1202, 'yaim'),
#  (1211, 'phoo'),
#  (1212, 'caj'),
#  (1220, 'khov'),
#  (1224, 'meb'),
#  (1224, 'twv'),
#  (1225, 'tsheb'),
#  (1231, 'cab'),
#  (1232, 'nqe'),
#  (1249, 'qhib'),
#  (1257, 'ntshav'),
#  (1262, 'tsw'),
#  (1263, 'siav'),
#  (1266, 'zov'),
#  (1275, 'cog'),
#  (1279, 'xob'),
#  (1280, 'plab'),
#  (1281, 'loo'),
#  (1287, 'thaiv'),
#  (1315, 'nuj'),
#  (1316, 'cawv'),
#  (1317, 'vaaj'),
#  (1318, 'nrauj'),
#  (1319, 'dim'),
#  (1320, 'tav'),
#  (1335, 'nkaum'),
#  (1335, 'xuas'),
#  (1337, 'nruab'),
#  (1351, 'sav'),
#  (1358, 'txiaj'),
#  (1361, 'tsiaj'),
#  (1368, 'nqis'),
#  (1376, 'ncees'),
#  (1383, 'cob'),
#  (1384, 'tshum'),
#  (1395, 'faib'),
#  (1396, 'hlau'),
#  (1399, 'nyiag'),
#  (1400, 'txhawj'),
#  (1402, 'dhia'),
#  (1403, 'ci'),
#  (1406, 'khib'),
#  (1407, 'ya'),
#  (1423, 'qhua'),
#  (1426, 'kos'),
#  (1428, 'taws'),
#  (1439, 'nai'),
#  (1442, 'ncig'),
#  (1458, 'aub'),
#  (1470, 'tswj'),
#  (1479, 'tshua'),
#  (1482, 'khaws'),
#  (1495, 'kaj'),
#  (1503, 'ntxub'),
#  (1507, 'ntaub'),
#  (1507, 'xab'),
#  (1514, 'thaam'),
#  (1521, 'swb'),
#  (1530, 'huab'),
#  (1531, 'khwv'),
#  (1539, 'kis'),
#  (1542, 'ntxias'),
#  (1545, 'lwj'),
#  (1557, 'kaw'),
#  (1558, 'tis'),
#  (1566, 'ncaws'),
#  (1571, 'nyoog'),
#  (1574, 'npawg'),
#  (1585, 'duab'),
#  (1591, 'ploj'),
#  (1596, 'txheej'),
#  (1619, 'nyuas'),
#  (1623, 'ntxim'),
#  (1632, 'sia'),
#  (1640, 'zam'),
#  (1654, 'tsheej'),
#  (1656, 'khoom'),
#  (1671, 'ab'),
#  (1678, 'twm'),
#  (1720, 'ris'),
#  (1724, 'npua'),
#  (1735, 'thoob'),
#  (1742, 'tw'),
#  (1743, 'nce'),
#  (1744, 'rab'),
#  (1746, 'cua'),
#  (1746, 'nqaij'),
#  (1750, 'tiav'),
#  (1780, 'fab'),
#  (1789, 'tsuj'),
#  (1791, 'nyuaj'),
#  (1794, 'tiv'),
#  (1797, 'ntes'),
#  (1797, 'tshwm'),
#  (1811, 'tshoob'),
#  (1824, 'zeb'),
#  (1831, 'txaj'),
#  (1834, 'kua'),
#  (1838, 'zaub'),
#  (1840, 'luj'),
#  (1840, 'quaj'),
#  (1841, 'thuam'),
#  (1849, 'dav'),
#  (1863, 'qaib'),
#  (1875, 'npau'),
#  (1889, 'qw'),
#  (1892, 'nrov'),
#  (1910, 'ntug'),
#  (1918, 'xws'),
#  (1920, 'ntsia'),
#  (1936, 'luam'),
#  (1937, 'ntoo'),
#  (1943, 'txeeb'),
#  (1955, 'pes'),
#  (1962, 'txiav'),
#  (1965, 'muam'),
#  (1969, 'khav'),
#  (2000, 'zab'),
#  (2002, 'teg'),
#  (2026, 'tsov'),
#  (2037, 'piv'),
#  (2045, 'ceev'),
#  (2048, 'hli'),
#  (2050, 'pauv'),
#  (2073, 'vwm'),
#  (2074, 'ntsuab'),
#  (2077, 'plig'),
#  (2084, 'nraug'),
#  (2094, 'qaab'),
#  (2136, 'pog'),
#  (2187, 'tuam'),
#  (2188, 'kas'),
#  (2189, 'ciaj'),
#  (2195, 'txhawb'),
#  (2209, 'caum'),
#  (2229, 'tsav'),
#  (2229, 'tshuaj'),
#  (2236, 'dub'),
#  (2250, 'hmo'),
#  (2254, 'aws'),
#  (2266, 'roob'),
#  (2270, 'txheeb'),
#  (2280, 'nqa'),
#  (2286, 'nub'),
#  (2300, 'ceg'),
#  (2303, 'nqi'),
#  (2310, 'hlwb'),
#  (2329, 'nyab'),
#  (2335, 'ntshaw'),
#  (2365, 'tooj'),
#  (2366, 'npaj'),
#  (2367, 'dlaab'),
#  (2377, 'thaj'),
#  (2412, 'xam'),
#  (2422, 'txhia'),
#  (2452, 'toj'),
#  (2462, 'ntaus'),
#  (2477, 'paab'),
#  (2480, 'plaub'),
#  (2484, 'tawv'),
#  (2494, 'saub'),
#  (2508, 'xub'),
#  (2529, 'puj'),
#  (2533, 'txij'),
#  (2541, 'tig'),
#  (2568, 'nrug'),
#  (2596, 'phom'),
#  (2596, 'quas'),
#  (2613, 'vam'),
#  (2616, 'lees'),
#  (2628, 'ca'),
#  (2639, 'nkawd'),
#  (2641, 'xaiv'),
#  (2659, 'txhaum'),
#  (2660, 'tsua'),
#  (2663, 'pawg'),
#  (2682, 'kab'),
#  (2689, 'ncauj'),
#  (2713, 'txwv'),
#  (2722, 'num'),
#  (2723, 'paj'),
#  (2746, 'miv'),
#  (2755, 'noog'),
#  (2758, 'noob'),
#  (2769, 'cuag'),
#  (2772, 'nyuj'),
#  (2797, 'qhuas'),
#  (2797, 'tawg'),
#  (2809, 'nav'),
#  (2844, 'suab'),
#  (2847, 'teev'),
#  (2848, 'xyuas'),
#  (2853, 'xov'),
#  (2855, 'liam'),
#  (2880, 'tsoom'),
#  (2882, 'faj'),
#  (2896, 'zoov'),
#  (2926, 'yaam'),
#  (2933, 'cuab'),
#  (2945, 'puag'),
#  (2953, 'lov'),
#  (2970, 'muas'),
#  (2993, 'so'),
#  (2998, 'yau'),
#  (3044, 'hawm'),
#  (3054, 'mos'),
#  (3105, 'hloov'),
#  (3112, 'sub'),
#  (3133, 'ntsej'),
#  (3134, 'cais'),
#  (3162, 'dev'),
#  (3215, 'neeb'),
#  (3237, 'mov'),
#  (3273, 'pw'),
#  (3291, 'ke'),
#  (3291, 'tais'),
#  (3321, 'xeeb'),
#  (3326, 'koob'),
#  (3327, 'nyeem'),
#  (3348, 'yav'),
#  (3354, 'sij'),
#  (3360, 'cev'),
#  (3372, 'yeeb'),
#  (3404, 'zos'),
#  (3410, 'mag'),
#  (3435, 'cav'),
#  (3477, 'luas'),
#  (3511, 'tuav'),
#  (3542, 'deb'),
#  (3560, 'taus'),
#  (3563, 'hav'),
#  (3600, 'taw'),
#  (3641, 'tshiab'),
#  (3645, 'txom'),
#  (3677, 'av'),
#  (3708, 'them'),
#  (3732, 'pum'),
#  (3737, 'laj'),
#  (3761, 'do'),
#  (3815, 'taug'),
#  (3825, 'hau'),
#  (3840, 'nram'),
#  (3864, 'tam'),
#  (3866, 'piav'),
#  (3876, 'ntsis'),
#  (3883, 'saum'),
#  (3887, 'nua'),
#  (3899, 'txawv'),
#  (3916, 'tshuav'),
#  (3920, 'xwm'),
#  (3930, 'ze'),
#  (3937, 'mog'),
#  (3968, 'zaj'),
#  (4001, 'hom'),
#  (4004, 'pib'),
#  (4006, 'taag'),
#  (4022, 'huv'),
#  (4028, 'nyaj'),
#  (4089, 'kub'),
#  (4161, 'ncaj'),
#  (4161, 'txhais'),
#  (4193, 'tsa'),
#  (4198, 'rog'),
#  (4226, 'rooj'),
#  (4303, 'ko'),
#  (4324, 'haum'),
#  (4332, 'yuam'),
#  (4348, 'nam'),
#  (4360, 'xa'),
#  (4368, 'quav'),
#  (4424, 'phooj'),
#  (4498, 'txuj'),
#  (4514, 'ywg'),
#  (4569, 'chim'),
#  (4687, 'tsawg'),
#  (4722, 'nyuag'),
#  (4889, 'txim'),
#  (4923, 'teeb'),
#  (4939, 'niaj'),
#  (4960, 'nas'),
#  (4975, 'tog'),
#  (4997, 'caij'),
#  (5020, 'cem'),
#  (5074, 'kho'),
#  (5082, 'mloog'),
#  (5086, 'liab'),
#  (5105, 'haus'),
#  (5125, 'wb'),
#  (5166, 'caag'),
#  (5202, 'neb'),
#  (5214, 'txug'),
#  (5288, 'pem'),
#  (5289, 'laug'),
#  (5453, 'kav'),
#  (5459, 'nrhiav'),
#  (5470, 'naj'),
#  (5570, 'qub'),
#  (5632, 'nkaus'),
#  (5650, 'tu'),
#  (5657, 'lo'),
#  (5666, 'hlob'),
#  (5693, 'nyias'),
#  (5731, 'pub'),
#  (5761, 'daim'),
#  (5831, 'nco'),
#  (5891, 'maj'),
#  (5901, 'poob'),
#  (5924, 'nug'),
#  (5969, 'ntsib'),
#  (5989, 'ntxhais'),
#  (6050, 'ntshe'),
#  (6058, 'mob'),
#  (6063, 'tiam'),
#  (6111, 'dej'),
#  (6146, 'meej'),
#  (6168, 'xaav'),
#  (6181, 'khiav'),
#  (6190, 'tsaug'),
#  (6212, 'nyuam'),
#  (6248, 'luaj'),
#  (6277, 'thawj'),
#  (6413, 'mej'),
#  (6414, 'leeg'),
#  (6469, 'dawb'),
#  (6497, 'ntev'),
#  (6556, 'txaus'),
#  (6562, 'yaj'),
#  (6563, 'nyiam'),
#  (6589, 'pob'),
#  (6605, 'lis'),
#  (6678, 'kam'),
#  (6692, 'chaw'),
#  (6790, 'tseg'),
#  (6840, 'ruam'),
#  (7090, 'tos'),
#  (7227, 'pov'),
#  (7266, 'xeem'),
#  (7286, 'koom'),
#  (7358, 'yim'),
#  (7378, 'ub'),
#  (7426, 'ntej'),
#  (7595, 'ntse'),
#  (7781, 'vaj'),
#  (7799, 'a'),
#  (7821, 'phem'),
#  (7839, 'ntshai'),
#  (8031, 'npaum'),
#  (8056, 'thaib'),
#  (8067, 'dhau'),
#  (8128, 'puab'),
#  (8150, 'chaws'),
#  (8303, 'nkauj'),
#  (8317, 'tsim'),
#  (8338, 'hnov'),
#  (8427, 'hluas'),
#  (8470, 'dag'),
#  (8532, 'haiv'),
#  (8559, 'ntxiv'),
#  (8598, 'kws'),
#  (8615, 'tij'),
#  (8631, 'npe'),
#  (8653, 'tib'),
#  (8730, 'tes'),
#  (8813, 'nom'),
#  (8819, 'yug'),
#  (8949, 'zog'),
#  (9040, 'yawm'),
#  (9053, 'sim'),
#  (9099, 'cai'),
#  (9180, 'dua'),
#  (9187, 'tsam'),
#  (9295, 'hlub'),
#  (9306, 'zaum'),
#  (9354, 'loj'),
#  (9395, 'raws'),
#  (9437, 'hu'),
#  (9469, 'sau'),
#  (9561, 'poj'),
#  (9600, 'pheej'),
#  (9645, 'nwg'),
#  (9663, 'txhua'),
#  (9709, 'laus'),
#  (9944, 'thov'),
#  (10022, 'coob'),
#  (10147, 'tshaj'),
#  (10169, 'muag'),
#  (10212, 'tswv'),
#  ...]

# %% [markdown]
# ## Partition the grouped splits into 50% swap and 50% keep

# %%
import torch

# %%
data = torch.load('../data/hmong/data_lid.pth')
split = torch.load('../data/hmong/split_grouped_lid_1.pth')

val_split = split['train']
val_sentences = {idx: data['sentences'][idx] for idx in val_split}
val_tags = {idx: data['tags'][idx] for idx in val_split if idx in data['tags']}

# %%
for (idx, tag) in val_tags.items():
    # positive sentences here
    sentence = val_sentences[idx]
    begin = tag.index(l2i['B'])
    ee_i = sentence[begin:begin+4]
    ee_w = list(map(i2w.__getitem__, ee_i))
    if len(ee_w) < 4:
        print(ee_w, 'incomplete')
        continue
    ee_in_val_elabs = tuple(ee_w) in valtest_sets[0]
    ee_in_train_elabs = tuple(ee_w) in train_sets[0]
    print('ee is in val_elabs: ', ee_in_val_elabs, 'in train_elabs', ee_in_train_elabs)
    if not (ee_in_val_elabs or ee_in_train_elabs):
        print(ee_w, 'not in either')
# Out:
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ['luag', 'vaj'] incomplete
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ['raug', 'phooj'] incomplete
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ['hav'] incomplete
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs False
# ['xu', 'UNK', 'xu', 'das'] not in either
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ['tas', 'zaj'] incomplete
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs False
# ['xu', 'UNK', 'xu', 'das'] not in either
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ...
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  True in train_elabs False
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ['ua', 'pab'] incomplete
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
# ee is in val_elabs:  False in train_elabs True
